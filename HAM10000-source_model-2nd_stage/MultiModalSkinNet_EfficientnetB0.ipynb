# %%
print("USING LARGE-SCALE DATASETS TO ENHANCE DIAGNOSIS IN LIMITED MULTI-SPECTRAL SKIN IMAGING")
print("Bachelor Thesis")
# Out:
# USING LARGE-SCALE DATASETS TO ENHANCE DIAGNOSIS IN LIMITED MULTI-SPECTRAL SKIN IMAGING
# Bachelor Thesis

# %% [markdown]
# # Connect with Google Drive

# %%
# !pip install opendatasets
import opendatasets as od
od.download("https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000")
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from opendatasets) (4.67.3)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (from opendatasets) (2.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from opendatasets) (8.3.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (6.3.0)
# Requirement already satisfied: jupytext in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (1.19.1)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.20 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (0.1.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (26.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (5.29.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.32.4)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle->opendatasets) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle->opendatasets) (0.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle->opendatasets) (5.10.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from jupytext->kaggle->opendatasets) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle->opendatasets) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle->opendatasets) (3.13)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle->opendatasets) (2026.4.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=1.0->jupytext->kaggle->opendatasets) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle->opendatasets) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle->opendatasets) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle->opendatasets) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.12/dist-packages (from nbformat->jupytext->kaggle->opendatasets) (5.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle->opendatasets) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle->opendatasets) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle->opendatasets) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle->opendatasets) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle->opendatasets) (4.9.6)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle->opendatasets) (4.15.0)
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: ngocbaotramtran
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000
# Downloading skin-cancer-mnist-ham10000.zip to ./skin-cancer-mnist-ham10000
# 100%|██████████| 5.20G/5.20G [02:05<00:00, 44.3MB/s]

# %% [markdown]
# # Download all libraries and packages needed

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import cv2
import os
import shutil
import itertools
import imutils
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.metrics import accuracy_score, balanced_accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import OneHotEncoder, StandardScaler


# import matplotlib as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
import torchvision.models as models
import timm
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
from torch.optim.lr_scheduler import CosineAnnealingLR

import random
import copy
import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(42)

# %%
# CUDA
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# GPU: NVIDIA A100-SXM4-80GB

# %%
num_workers=2

# %%
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(42)

# %% [markdown]
# # View Original Dataset

# %%
skinDf = pd.read_csv('/content/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')
skinDf
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
# skinDf.columns #- To view all the columns (features) of the metadata table

# %%
# skinDf['dx'].unique() #- See all the possible values of the column dx

# %%
classes_to_keep = ['bcc', 'mel', 'bkl', 'nv']
skinDf = skinDf[skinDf['dx'].isin(classes_to_keep)]
skinDf['dx'].value_counts()

# when filter DataFrame = .isin(), pandas still keeps the same indexes from original DataFrame - skinDf
# Out:
# dx
# nv     6705
# mel    1113
# bkl    1099
# bcc     514
# Name: count, dtype: int64

# %%
skinDf = skinDf.reset_index(drop=True)
#it will drop the old indexes - and get the new continuous indexes

# %%
skinDf #view the new indexes
# Out:
#         lesion_id      image_id   dx    dx_type   age     sex localization
# 0     HAM_0000118  ISIC_0027419  bkl      histo  80.0    male        scalp
# 1     HAM_0000118  ISIC_0025030  bkl      histo  80.0    male        scalp
# 2     HAM_0002730  ISIC_0026769  bkl      histo  80.0    male        scalp
# 3     HAM_0002730  ISIC_0025661  bkl      histo  80.0    male        scalp
# 4     HAM_0001466  ISIC_0031633  bkl      histo  75.0    male          ear
# ...           ...           ...  ...        ...   ...     ...          ...
# 9426  HAM_0000102  ISIC_0031547   nv  consensus  20.0    male         back
# 9427  HAM_0000102  ISIC_0032221   nv  consensus  20.0    male         back
# 9428  HAM_0005314  ISIC_0030693   nv  consensus  40.0    male         neck
# 9429  HAM_0003322  ISIC_0031649   nv  consensus  50.0  female         face
# 9430  HAM_0003521  ISIC_0032258  mel      histo  70.0  female         back
#
# [9431 rows x 7 columns]

# %%
# Check NaN values
nan_count = skinDf.isnull().sum()
print("NaN values in metadata:\n", nan_count)

# Expected HAM10000 images based on metadata
expected_images = skinDf['image_id'].nunique()
print(f"\nTotal expected images from HAM10000 metadata: {expected_images}")

expected_lesions = skinDf['lesion_id'].nunique()
print(f"\nTotal expected lesion from HAM10000 metadata: {expected_lesions}")
# Out:
# NaN values in metadata:
#  lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age             57
# sex              0
# localization     0
# dtype: int64
#
# Total expected images from HAM10000 metadata: 9431
#
# Total expected lesion from HAM10000 metadata: 7071

# %%
# label encoding
label_map = {
    'bcc': 0,
    'bkl': 1,
    'mel': 2,
    'nv': 3
}

skinDf['label'] = skinDf['dx'].map(label_map) #label - for training -> so right now the skinDf will have one more column
print(skinDf[['dx', 'label']].head())
# Out:
#     dx  label
# 0  bkl      1
# 1  bkl      1
# 2  bkl      1
# 3  bkl      1
# 4  bkl      1

# %%
img_dir1 = "/content/skin-cancer-mnist-ham10000/HAM10000_images_part_1"
img_dir2 = "/content/skin-cancer-mnist-ham10000/HAM10000_images_part_2"

def get_image_path(image_id):
    p1 = os.path.join(img_dir1, image_id + ".jpg")
    p2 = os.path.join(img_dir2, image_id + ".jpg")
    if os.path.exists(p1):
        return p1
    elif os.path.exists(p2):
        return p2
    else:
        return None

skinDf['image_path'] = skinDf['image_id'].apply(get_image_path)
skinDf = skinDf[skinDf['image_path'].notnull()].copy()

print("Missing image paths:", skinDf['image_path'].isnull().sum())
print("Final rows:", len(skinDf))
# Out:
# Missing image paths: 0
# Final rows: 9431

# %%
print("Columns of skinDf now:", skinDf.columns.tolist())
# Out:
# Columns of skinDf now: ['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization', 'label', 'image_path']

# %% [markdown]
# # Hair Removal

# %%
# HAIR REMOVAL
HAIR_PIXEL_THRESHOLD = 500

kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7,7))  # kernel for blackhat # Original is (9,9) -> I changed to (7,7) -> less aggressive

hair_removed_dir = "/content/hair_removed"
os.makedirs(hair_removed_dir, exist_ok=True)

def remove_hair(row):
    image_id = row['image_id']
    save_path = os.path.join(hair_removed_dir, f"{image_id}.png")

    # If it has already been processed, skip this step (important when running again)
    if os.path.exists(save_path):
        return save_path

    img = cv2.imread(row['image_path'])
    if img is None:
        return row['image_path']  # fallback if reading error occurs

    # Step 1: Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Step 2: Blackhat to find hair
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)

    # Step 3: Threshold to create a hair mask
    _, mask = cv2.threshold(blackhat, 20, 255, cv2.THRESH_BINARY) #Original the theshold(blackhat, 10, 255, cv2.THRESH_BINARY) - I changed the second parameter from 10 to 20

    hair_pixels = np.sum(mask > 0)
    if hair_pixels < HAIR_PIXEL_THRESHOLD:
        cv2.imwrite(save_path, img)  # lưu ảnh gốc không đổi
        return save_path

    # Step 4: Inpaint hair removal
    # dst_telea = cv2.inpaint(img, mask, 5, cv2.INPAINT_TELEA) #radius has been changed from 1 to 5
    dst    = cv2.inpaint(img, mask, 5, cv2.INPAINT_NS)

    cv2.imwrite(save_path, dst)
    return save_path

tqdm.pandas()
skinDf['image_path_cleaned'] = skinDf.progress_apply(remove_hair, axis=1) # So this will be commented
print("\nHair removal done!")
# Out:
# 100%|██████████| 9431/9431 [05:40<00:00, 27.66it/s]
# Hair removal done!

# %% [markdown]
# # Change RGB images to R images, G images, B images

# %% [markdown]
# ## RGB already processed and has been stored in the drive (so if run again - a lot of GPU will run out)
#
# ```python
# skinDf[['path_R', 'path_G', 'path_B']] = skinDf.progress_apply(
#     save_rgb_channels, axis=1, result_type='expand'
# )
# ```
# This code - just comment it- then the gpu will be fine

# %%
#  R, G, B for the entire data
base_dir = "/content/multispectral_sim"
for channel in ["R", "G", "B"]:
    os.makedirs(os.path.join(base_dir, channel), exist_ok=True)

def save_rgb_channels(row):
    img = cv2.imread(row['image_path_cleaned'])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    image_id = row['image_id']

    path_R = f"{base_dir}/R/{image_id}_R.png"
    path_G = f"{base_dir}/G/{image_id}_G.png"
    path_B = f"{base_dir}/B/{image_id}_B.png"

    cv2.imwrite(path_R, img[:, :, 0])
    cv2.imwrite(path_G, img[:, :, 1])
    cv2.imwrite(path_B, img[:, :, 2])

    return path_R, path_G, path_B

tqdm.pandas()
skinDf[['path_R', 'path_G', 'path_B']] = skinDf.progress_apply(
    save_rgb_channels, axis=1, result_type='expand'
)
# Out:
# 100%|██████████| 9431/9431 [03:32<00:00, 44.46it/s]

# %%
base_dir = "/content/multispectral_sim"

for channel in ["R", "G", "B"]:
    path = os.path.join(base_dir, channel)
    num_images = len(os.listdir(path))
    print(f"{channel}: {num_images} images")
# Out:
# R: 9431 images
# G: 9431 images
# B: 9431 images

# %% [markdown]
# ## Original - Number of images per class - Before Split

# %%
# Count the number of images by class — before and after channel separation
label_map = {
    'bcc': 0,
    'bkl': 1,
    'mel': 2,
    'nv': 3
}

print("=" * 60)
print(f"{'Class (dx)':<12} {'Label':<8} {'RGB (original)':<12} {'R':<8} {'G':<8} {'B':<8} {'Total R+G+B'}")
print("=" * 60)

for dx, label in label_map.items():
    class_df = skinDf[skinDf['dx'] == dx]

    count_rgb = len(class_df)           # number of original photos
    count_R = len(class_df['path_R'])   # = count_rgb because each image → 1 R channel
    count_G = len(class_df['path_G'])
    count_B = len(class_df['path_B'])
    total_channels = count_R + count_G + count_B

    print(f"{dx:<12} {label:<8} {count_rgb:<12} {count_R:<8} {count_G:<8} {count_B:<8} {total_channels}")

print("=" * 60)

# Total
total_rgb = len(skinDf)
total_all = total_rgb * 3
print(f"{'TOTAL':<12} {'':<8} {total_rgb:<12} {total_rgb:<8} {total_rgb:<8} {total_rgb:<8} {total_all}")
# Out:
# ============================================================
# Class (dx)   Label    RGB (original) R        G        B        Total R+G+B
# ============================================================
# bcc          0        514          514      514      514      1542
# bkl          1        1099         1099     1099     1099     3297
# mel          2        1113         1113     1113     1113     3339
# nv           3        6705         6705     6705     6705     20115
# ============================================================
# TOTAL                 9431         9431     9431     9431     28293

# %% [markdown]
# RGB = R = G = B

# %% [markdown]
# # After splitting

# %% [markdown]
# # Split the dataset - Five Fold Split

# %%
def create_stratified_group_folds(df, group_col='lesion_id', label_col='label', n_splits=5):
    sgkf = StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=42)

    X = df.index.values
    y = df[label_col].values
    groups = df[group_col].values

    folds = []
    for fold_idx, (train_idx, val_idx) in enumerate(sgkf.split(X, y, groups)):
        train_fold_df = df.iloc[train_idx].reset_index(drop=True).copy()
        val_fold_df = df.iloc[val_idx].reset_index(drop=True).copy()
        folds.append((fold_idx, train_fold_df, val_fold_df))

    return folds

# %%
folds = create_stratified_group_folds(skinDf, group_col='lesion_id', label_col='label', n_splits=5)

print(f"Number of folds: {len(folds)}")
for fold_idx, train_fold_df, val_fold_df in folds:
    print(f"\nFold {fold_idx+1}")
    print("Train rows:", len(train_fold_df), "| Train lesions:", train_fold_df['lesion_id'].nunique())
    print("Val rows  :", len(val_fold_df), "| Val lesions  :", val_fold_df['lesion_id'].nunique())
# Out:
# Number of folds: 5
#
# Fold 1
# Train rows: 7585 | Train lesions: 5656
# Val rows  : 1846 | Val lesions  : 1415
#
# Fold 2
# Train rows: 7507 | Train lesions: 5656
# Val rows  : 1924 | Val lesions  : 1415
#
# Fold 3
# Train rows: 7531 | Train lesions: 5657
# Val rows  : 1900 | Val lesions  : 1414
#
# Fold 4
# Train rows: 7560 | Train lesions: 5657
# Val rows  : 1871 | Val lesions  : 1414
#
# Fold 5
# Train rows: 7541 | Train lesions: 5658
# Val rows  : 1890 | Val lesions  : 1413

# %%
# Table showing the number of photos BEFORE augmentation, BY FOLD
label_map_display = {0: 'bcc', 1: 'bkl', 2: 'mel', 3: 'nv'}

for fold_idx, train_fold_df, val_fold_df in folds:
    for split_name, split_df in [("TRAIN", train_fold_df), ("VAL", val_fold_df)]:

        print(f"\nFold {fold_idx+1} — {split_name}")
        print("=" * 75)
        print(f"{'Class':<8} {'Label':<8} {'RGB':<8} {'R':<8} {'G':<8} {'B':<8} {'Total R+G+B':<14} {'%RGB'}")
        print("=" * 75)

        total_rgb = len(split_df)
        missing = []  # Add a list to track missing classes

        for label, dx in label_map_display.items():
            class_df = split_df[split_df['label'] == label]
            count_rgb = len(class_df)
            count_R   = count_rgb
            count_G   = count_rgb
            count_B   = count_rgb
            total_channels = count_R + count_G + count_B
            pct = count_rgb / total_rgb * 100 if total_rgb > 0 else 0

            print(f"{dx:<8} {label:<8} {count_rgb:<8} {count_R:<8} {count_G:<8} {count_B:<8} {total_channels:<14} {pct:.2f}%")

            if count_rgb == 0:  # check missing
                missing.append(dx)

        print("=" * 75)
        total_channels_all = total_rgb * 3

        total_pct = sum(
            len(split_df[split_df['label'] == label]) / total_rgb * 100
            for label in label_map_display.keys()
        ) if total_rgb > 0 else 0

        print(f"{'TOTAL':<8} {'':<8} {total_rgb:<8} {total_rgb:<8} {total_rgb:<8} {total_rgb:<8} {total_channels_all:<14} {total_pct:.2f}%")


        print(f"Missing classes: {missing if missing else 'None'}")
# Out:
# Fold 1 — TRAIN
# ===========================================================================
# Class    Label    RGB      R        G        B        Total R+G+B    %RGB
# ===========================================================================
# bcc      0        413      413      413      413      1239           5.44%
# bkl      1        921      921      921      921      2763           12.14%
# mel      2        896      896      896      896      2688           11.81%
# nv       3        5355     5355     5355     5355     16065          70.60%
# ===========================================================================
# TOTAL             7585     7585     7585     7585     22755          100.00%
# Missing classes: None
#
# Fold 1 — VAL
# ===========================================================================
# Class    Label    RGB      R        G        B        Total R+G+B    %RGB
# ===========================================================================
# bcc      0        101      101      101      101      303            5.47%
# bkl      1        178      178      178      178      534            9.64%
# mel      2        217      217      217      217      651            11.76%
# nv       3        1350     1350     1350     1350     4050           73.13%
# ===========================================================================
# TOTAL             1846     1846     1846     1846     5538           100.00%
# Missing classes: None
#
# Fold 2 — TRAIN
# ===========================================================================
# Class    Label    RGB      R        G        B        Total R+G+B    %RGB
# ===========================================================================
# bcc      0        423      423      423      423      1269           5.63%
# bkl      1        888      888      888      888      2664           11.83%
# mel      2        856      856      856      856      2568           11.40%
# nv       3        5340     5340     5340     5340     16020          71.13%
# ===========================================================================
# TOTAL             7507     7507     7507     7507     22521          100.00%
# Missing classes: None
#
# Fold 2 — VAL
# ===========================================================================
# Class    Label    RGB      R        G        B        Total R+G+B    %RGB
# ===========================================================================
# bcc      0        91       91       91       91       273            4.73%
# bkl      1        211      211      211      211      633            10.97%
# mel      2        257      257      257      257      771            13.36%
# nv       3        1365     1365     1365     1365     4095           70.95%
# ===========================================================================
# TOTAL             1924     1924     1924     1924     5772           100.00%
# Missing classes: None
#
# Fold 3 — TRAIN
# ===========================================================================
# Class    Label    RGB      R        G        B        Total R+G+B    %RGB
# ===========================================================================
# bcc      0        397      397      397      397      1191           5.27%
# bkl      1        838      838      838      838      2514           11.13%
# mel      2        909      909      909      909      2727           12.07%
# nv       3        5387     5387     5387     5387     16161          71.53%
# ===========================================================================
# TOTAL             7531     7531     7531     7531     22593          100.00%
# Missing classes: None
#
# Fold 3 — VAL
# ===========================================================================
# Class    Label    RGB      R        G        B        Total R+G+B    %RGB
# ===========================================================================
# bcc      0        117      117      117      117      351            6.16%
# bkl      1        261      261      261      261      783            13.74%
# mel      2        204      204      204      204      612            10.74%
# nv       3        1318     1318     1318     1318     3954           69.37%
# ===========================================================================
# TOTAL             1900     1900     1900     1900     5700           100.00%
# Missing classes: None
#
# Fold 4 — TRAIN
# ===========================================================================
# Class    Label    RGB      R        G        B        Total R+G+B    %RGB
# ===========================================================================
# bcc      0        420      420      420      420      1260           5.56%
# bkl      1        881      881      881      881      2643           11.65%
# mel      2        895      895      895      895      2685           11.84%
# nv       3        5364     5364     5364     5364     16092          70.95%
# ===========================================================================
# TOTAL             7560     7560     7560     7560     22680          100.00%
# Missing classes: None
#
# Fold 4 — VAL
# ===========================================================================
# Class    Label    RGB      R        G        B        Total R+G+B    %RGB
# ===========================================================================
# bcc      0        94       94       94       94       282            5.02%
# bkl      1        218      218      218      218      654            11.65%
# mel      2        218      218      218      218      654            11.65%
# nv       3        1341     1341     1341     1341     4023           71.67%
# ===========================================================================
# TOTAL             1871     1871     1871     1871     5613           100.00%
# Missing classes: None
#
# Fold 5 — TRAIN
# ===========================================================================
# Class    Label    RGB      R        G        B        Total R+G+B    %RGB
# ===========================================================================
# bcc      0        403      403      403      403      1209           5.34%
# bkl      1        868      868      868      868      2604           11.51%
# mel      2        896      896      896      896      2688           11.88%
# nv       3        5374     5374     5374     5374     16122          71.26%
# ===========================================================================
# TOTAL             7541     7541     7541     7541     22623          100.00%
# Missing classes: None
#
# Fold 5 — VAL
# ===========================================================================
# Class    Label    RGB      R        G        B        Total R+G+B    %RGB
# ===========================================================================
# bcc      0        111      111      111      111      333            5.87%
# bkl      1        231      231      231      231      693            12.22%
# mel      2        217      217      217      217      651            11.48%
# nv       3        1331     1331     1331     1331     3993           70.42%
# ===========================================================================
# TOTAL             1890     1890     1890     1890     5670           100.00%
# Missing classes: None

# %%
for fold_idx, train_fold_df, val_fold_df in folds:
    train_lesions = set(train_fold_df['lesion_id'])
    val_lesions = set(val_fold_df['lesion_id'])

    overlap = train_lesions & val_lesions
    print(f"Fold {fold_idx+1} lesion overlap:", len(overlap))
# Out:
# Fold 1 lesion overlap: 0
# Fold 2 lesion overlap: 0
# Fold 3 lesion overlap: 0
# Fold 4 lesion overlap: 0
# Fold 5 lesion overlap: 0

# %% [markdown]
# # Metadata preprocessing

# %% [markdown]
# # See the distribution after selecting the attributes

# %%
fig = px.bar(skinDf['dx'].value_counts(), x=skinDf['dx'].value_counts().index, y=skinDf['dx'].value_counts().values,
             labels={'x': 'Class', 'y': 'Count'}, title='Distribution of Classes') # Chart showing the number of images for each disease class
fig.show()

# Age distribution
fig = px.histogram(skinDf, x='age', title='Age Distribution') # Histogram of the patient's age
fig.show()

# Sex distribution
fig = px.bar(skinDf['sex'].value_counts(), x=skinDf['sex'].value_counts().index, y=skinDf['sex'].value_counts().values,
             labels={'x': 'Sex', 'y': 'Count'}, title='Sex Distribution') # This chart shows the number of males vs. females.
fig.show()

# Localization distribution
fig = px.bar(skinDf['localization'].value_counts(), x=skinDf['localization'].value_counts().index, y=skinDf['localization'].value_counts().values,
             labels={'x': 'Localization', 'y': 'Count'}, title='Localization Distribution') # Localization refers to the location of an injury on the body
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="27545a4c-e3e7-4b2d-81f2-a587704754c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27545a4c-e3e7-4b2d-81f2-a587704754c4")) {                    Plotly.newPlot(                        "27545a4c-e3e7-4b2d-81f2-a587704754c4",                        [{"alignmentgroup":"True","hovertemplate":"Class=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["nv","mel","bkl","bcc"],"xaxis":"x","y":[6705,1113,1099,514],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"s ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="50990a64-a3d2-492f-8adb-10f1ccd199dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50990a64-a3d2-492f-8adb-10f1ccd199dc")) {                    Plotly.newPlot(                        "50990a64-a3d2-492f-8adb-10f1ccd199dc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[80.0,80.0,80.0,80.0,75.0,75.0,60.0,60.0,70.0,70.0,55.0,85.0,85.0,70.0,70.0,65.0,75.0,75.0,70.0,70.0,70.0,60.0,60.0,75.0,75.0,40.0,40.0,40.0,40.0,70.0,70.0,60.0,60.0,80.0,80.0,85.0,85.0,85.0,85.0,85.0,85.0,60.0,60.0,50.0,50.0,50.0,75.0,75.0,40.0,40.0,80.0,75.0,75.0,45.0,45.0,70.0,75.0,75.0,60.0,50.0,75.0,75.0,75.0,75.0,70.0,40.0,40.0,60.0,60.0,70.0,70.0,70.0,70.0,75.0,75.0,60.0,60.0,60.0,75.0,75.0,75.0,75.0,40.0,40.0,40.0,40.0,35.0,35.0,80.0,80.0,60.0,60.0,60.0,65.0,65.0,60.0,70.0,40.0,40.0,70.0,70.0,85.0,75.0,75.0,55.0,65.0,65.0,50.0,50.0,55.0,55.0,65.0,65.0,85.0,85.0,50.0,50.0,0.0,0.0,75.0,60.0,55.0,55.0,55.0,55.0,55.0,75.0,75.0,85.0,85.0,85.0,50.0,50.0,50.0,55.0,55.0,55.0,60.0,55.0,55.0,65.0,85.0,85.0,75.0,75.0,75.0,75.0,50.0,50.0,50.0,60.0,60.0,60.0,45.0,45.0,45.0,80.0,80.0,80.0,80.0,70.0,45.0,45.0,45.0,50.0,50.0,50.0,40.0,40.0,80.0,80.0,60.0,60.0,60.0,60.0,60.0,60.0,60.0,60.0,60.0,75.0,75.0,60.0,60.0,60.0,60.0,85.0,85.0,85.0,85.0,85.0,65.0,65.0,85.0,85.0,60.0,60.0,60.0,80.0,80.0,65.0,80.0,80.0,45.0,45.0,45.0,55.0,55.0,85.0,85.0,45.0,45.0,40.0,40.0,40.0,40.0,35.0,35.0,80.0,80.0,80.0,70.0,70.0,60.0,60.0,60.0,75.0,75.0,75.0,75.0,75.0,75.0,75.0,75.0,80.0,80.0,65.0,65.0,65.0,85.0,85.0,50.0,50.0,50.0,65.0,70.0,70.0,70.0,75.0,75.0,75.0,75.0,75.0,65.0,65.0,75.0,75.0,60.0,60.0,60.0,60.0,60.0,80.0,80.0,80.0,80.0,70.0,85.0,40.0,65.0,45.0,85.0,65.0,55.0,70.0,50.0,70.0,75.0,75.0,55.0,70.0,50.0,50.0,50.0,50.0,80.0,50.0,70.0,60.0,55.0,80.0,70.0,60.0,65.0,70.0,50.0,55.0,65.0,80.0,50.0,75.0,65.0,60.0,80.0,85.0,45.0,55.0,40.0,75.0,75.0,60.0,60.0,65.0,80.0,50.0,70.0,80.0,60.0,65.0,60.0,75.0,70.0,40.0,80.0,65.0,60.0,85.0,60.0,65.0,60.0,50.0,50.0,80.0,50.0,40.0,85.0,70.0,70.0,70.0,35.0,70.0,70.0,40.0,85.0,50.0,70.0,55.0,45.0,65.0,50.0,65.0,80.0,65.0,85.0,85.0,60.0,75.0,85.0,75.0,65.0,65.0,65.0,65.0,65.0,85.0,60.0,60.0,70.0,45.0,80.0,65.0,75.0,65.0,75.0,35.0,75.0,35.0,75.0,70.0,60.0,65.0,60.0,60.0,85.0,60.0,70.0,45.0,45.0,70.0,40.0,45.0,70.0,70.0,65.0,65.0,55.0,55.0,75.0,55.0,85.0,85.0,85.0,50.0,75.0,75.0,65.0,70.0,50.0,80.0,80.0,70.0,70.0,40.0,65.0,60.0,60.0,70.0,65.0,70.0,85.0,80.0,65.0,40.0,75.0,75.0,75.0,70.0,50.0,50.0,35.0,70.0,40.0,85.0,60.0,70.0,70.0,70.0,35.0,75.0,75.0,75.0,80.0,70.0,60.0,85.0,85.0,85.0,85.0,70.0,55.0,70.0,65.0,70.0,60.0,60.0,65.0,50.0,80.0,75.0,55.0,55.0,50.0,50.0,75.0,40.0,40.0,75.0,70.0,35.0,70.0,70.0,70.0,50.0,75.0,75.0,50.0,50.0,70.0,60.0,30.0,55.0,55.0,60.0,60.0,75.0,75.0,65.0,70.0,60.0,45.0,45.0,70.0,75.0,55.0,60.0,55.0,50.0,50.0,70.0,80.0,60.0,60.0,75.0,65.0,75.0,75.0,70.0,70.0,80.0,80.0,50.0,80.0,85.0,75.0,75.0,75.0,75.0,60.0,55.0,70.0,80.0,80.0,80.0,75.0,75.0,70.0,60.0,70.0,50.0,65.0,70.0,50.0,70.0,60.0,65.0,60.0,60.0,80.0,75.0,55.0,85.0,55.0,55.0,55.0,55.0,55.0,40.0,40.0,40.0,35.0,55.0,70.0,70.0,50.0,65.0,45.0,70.0,70.0,65.0,50.0,80.0,45.0,65.0,80.0,55.0,45.0,55.0,60.0,60.0,60.0,60.0,85.0,40.0,40.0,70.0,45.0,85.0,85.0,55.0,75.0,85.0,70.0,60.0,65.0,55.0,55.0,60.0,60.0,65.0,50.0,55.0,85.0,75.0,65.0,65.0,70.0,70.0,70.0,50.0,50.0,65.0,70.0,65.0,75.0,60.0,50.0,70.0,55.0,70.0,35.0,50.0,70.0,70.0,65.0,70.0,80.0,75.0,60.0,75.0,55.0,45.0,45.0,75.0,45.0,50.0,70.0,70.0,85.0,85.0,45.0,45.0,45.0,65.0,45.0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5a7aae3c-e6b5-4523-9030-ff67bf33cb3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a7aae3c-e6b5-4523-9030-ff67bf33cb3a")) {                    Plotly.newPlot(                        "5a7aae3c-e6b5-4523-9030-ff67bf33cb3a",                        [{"alignmentgroup":"True","hovertemplate":"Sex=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["male","female","unknown"],"xaxis":"x","y":[5053,4321,57],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatte ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1887efae-143c-479e-a237-3d7b98c18775" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1887efae-143c-479e-a237-3d7b98c18775")) {                    Plotly.newPlot(                        "1887efae-143c-479e-a237-3d7b98c18775",                        [{"alignmentgroup":"True","hovertemplate":"Localization=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["back","lower extremity","trunk","upper extremity","abdomen","face","chest","foot","unknown","neck","scalp","hand","ear","genital","acral"],"xaxis":"x","y":[2139,1903,1372,1021,986,624,389,317,234,155,112,72,53,47,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"p ...

# %%
# View to see - then can select mean or mode
import seaborn as sns
import scipy.stats as stats


# Histogram with KDE (Smooth Curve)
sns.histplot(skinDf['age'], bins=30, kde=True)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution in HAM10000 Dataset")
plt.show()

# Skewness Check
skewness = skinDf['age'].skew()

# Print Result
if abs(skewness) < 0.5:
    print(" The data is *Normal (Symmetrical). Use Mean*.")
elif skewness > 0.5:
    print(" The data is *Right Skewed. Use Median*.")
else:
    print(" The data is *Left Skewed. Use Median*.")
# Out:
#  The data is *Normal (Symmetrical). Use Mean*.

# %%
def preprocess_metadata_per_fold(train_df, val_df, num_cols=['age'], cat_cols=['sex', 'localization'], target_col='label'):
    X_train_raw = train_df[num_cols + cat_cols].copy()
    X_val_raw = val_df[num_cols + cat_cols].copy()

    y_train = train_df[target_col].values
    y_val = val_df[target_col].values

    age_mean = X_train_raw['age'].mean()

    X_train_raw['age'] = X_train_raw['age'].fillna(age_mean)
    X_val_raw['age'] = X_val_raw['age'].fillna(age_mean)

    try:
        encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
    except TypeError:
        encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)

    X_train_cat = encoder.fit_transform(X_train_raw[cat_cols])
    X_val_cat = encoder.transform(X_val_raw[cat_cols])

    scaler = StandardScaler()
    X_train_num = scaler.fit_transform(X_train_raw[num_cols])
    X_val_num = scaler.transform(X_val_raw[num_cols])

    X_train_meta = np.concatenate([X_train_num, X_train_cat], axis=1)
    X_val_meta = np.concatenate([X_val_num, X_val_cat], axis=1)

    return X_train_meta, X_val_meta, y_train, y_val, encoder, scaler

# %% [markdown]
# # Preprocess image

# %%
class AddGaussianNoise(object):
    def __init__(self, mean=0.0, std_range=(0.01, 0.05), p=0.5):
        self.mean = mean
        self.std_range = std_range
        self.p = p

    def __call__(self, tensor):
        if random.random() < self.p:
            std = random.uniform(self.std_range[0], self.std_range[1])
            noise = torch.randn_like(tensor) * std + self.mean
            tensor = tensor + noise
            tensor = torch.clamp(tensor, 0.0, 1.0)
        return tensor

# %%
from torchvision import transforms

# Light augmentation for all training images
train_transform_base = transforms.Compose([
    # transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(224, scale=(0.85, 1.0)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.ColorJitter(brightness=0.15, contrast=0.15), 
    transforms.ToTensor(),
    AddGaussianNoise(mean=0.0, std_range=(0.01, 0.03), p=0.3), 
    transforms.Normalize(mean=[0.449],
                         std=[0.226])
])


# Stronger augmentation for minority classes only
train_transform_minority = transforms.Compose([
    # transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)), 
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomPerspective(distortion_scale=0.15, p=0.2), 
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.1, hue=0.05),  
    
    transforms.ToTensor(),
    AddGaussianNoise(mean=0.0, std_range=(0.01, 0.05), p=0.4),  
    transforms.Normalize(mean=[0.449],
                         std=[0.226]),
    transforms.RandomErasing(p=0.3, scale=(0.02, 0.1), ratio=(0.3, 3.3))  
])


eval_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.449],
                         std=[0.226])
])

# %%
minority_class_ids = {0, 1, 2}

# %%
from torch.utils.data import Dataset
from PIL import Image


class HAM10000Dataset(Dataset):
    def __init__(self, df, meta_features, labels,
                 base_transform=None,
                 minority_transform=None,
                 eval_transform=None,
                 minority_class_ids=None,
                 minority_aug_prob=0.7,
                 training=True):

        self.df = df.reset_index(drop=True)
        self.meta_features = meta_features
        self.labels = labels
        self.base_transform = base_transform
        self.minority_transform = minority_transform
        self.eval_transform = eval_transform
        self.minority_class_ids = minority_class_ids if minority_class_ids is not None else set()
        self.minority_aug_prob = minority_aug_prob
        self.training = training

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        # Read 3 separate images of seperate channels instead of 1 RGB image
        path_R = self.df.loc[idx, 'path_R']
        path_G = self.df.loc[idx, 'path_G']
        path_B = self.df.loc[idx, 'path_B']

        # Each image is grayscale 1 channel → copy it to 3 channels so EfficientNet can receive it
        img_R = Image.open(path_R).convert('L') # convert('L')
        img_G = Image.open(path_G).convert('L')
        img_B = Image.open(path_B).convert('L')

        label = int(self.labels[idx])

        # Apply transform to each image
        if self.training:
            if (
                label in self.minority_class_ids
                and self.minority_transform is not None
                and random.random() < self.minority_aug_prob
            ):
                img_R = self.minority_transform(img_R)
                img_G = self.minority_transform(img_G)
                img_B = self.minority_transform(img_B)
            elif self.base_transform is not None:
                img_R = self.base_transform(img_R)
                img_G = self.base_transform(img_G)
                img_B = self.base_transform(img_B)
        else:
            if self.eval_transform is not None:
                img_R = self.eval_transform(img_R)
                img_G = self.eval_transform(img_G)
                img_B = self.eval_transform(img_B)

        meta = torch.tensor(self.meta_features[idx], dtype=torch.float32)
        label = torch.tensor(label, dtype=torch.long)

        # Return 3 separate images instead of 1
        return img_R, img_G, img_B, meta, label

# %%
# WeightedRandomSampler and Class Weights Coefficients

# %%
from torch.utils.data import DataLoader, WeightedRandomSampler

def build_loaders_for_fold(train_df, val_df, batch_size=32):
    X_train_meta, X_val_meta, y_train, y_val, encoder, scaler = preprocess_metadata_per_fold(train_df, val_df)

    train_dataset = HAM10000Dataset(
        df=train_df,
        meta_features=X_train_meta,
        labels=y_train,
        base_transform=train_transform_base,
        minority_transform=train_transform_minority,
        eval_transform=None,
        minority_class_ids={0, 1, 2}, # ONLY bcc (0) and mel (2), remove bkl (1)
        minority_aug_prob=0.7, 
        training=True
    )

    val_dataset = HAM10000Dataset(
        df=val_df,
        meta_features=X_val_meta,
        labels=y_val,
        eval_transform=eval_transform,
        training=False
    )

    num_classes = len(np.unique(y_train))
    class_counts = np.bincount(y_train, minlength=num_classes)
    class_counts = np.maximum(class_counts, 1) # avoid division by zero

    # Weight cho loss function (inverse frequency, normalized)
    class_weights = class_counts.sum() / (num_classes * class_counts)
    # class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32)

    # Weight for each sample (for use by the sampler)
    # Each sample receives the weight of the class it belongs to.
    sample_weights = class_weights[y_train]  # shape: (len(y_train),) ##

    sampler = WeightedRandomSampler(
        weights=torch.DoubleTensor(sample_weights),
        num_samples=len(sample_weights),
        replacement=True,
        generator=torch.Generator().manual_seed(42)
    ) ##

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        sampler=sampler,         # for the purpose - balance
        drop_last=True,
        num_workers=2,
        pin_memory=True,
        worker_init_fn=seed_worker,
        generator=g
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        drop_last=False,
        num_workers=2,
        pin_memory=True,
        worker_init_fn=seed_worker,
        generator=g
    )

    metadata_dim = X_train_meta.shape[1]

    return train_loader, val_loader, metadata_dim

# %%
fold_idx, train_df, val_df = folds[0]

train_loader, val_loader, metadata_dim = build_loaders_for_fold(
    train_df, val_df, batch_size=32
)

# %% [markdown]
# # Simulation to see the distribution - images per class for each fold
# Table showing the number of images after augmentation by class.

# %%
label_map_display = {0: 'bcc', 1: 'bkl', 2: 'mel', 3: 'nv'}

# To see the distribution of classes in the training set -> Uncomment these
# for fold_idx, train_fold_df, val_fold_df in folds:
#     train_loader_check, _, _ = build_loaders_for_fold(
#         train_fold_df, val_fold_df, batch_size=32
#     )

#     label_counts = [0, 0, 0, 0]
#     for img_R, img_G, img_B, meta, labels in train_loader_check:
#         for l in labels:
#             label_counts[l.item()] += 1

#     total = sum(label_counts)
#     print(f"\nFold {fold_idx+1} — TRAIN (Actual number after WeightedRandomSampler, 1 epoch)")
#     print("=" * 55)
#     print(f"{'Class':<8} {'Count':<10} {'%'}")
#     print("=" * 55)
#     for label, dx in label_map_display.items():
#         count = label_counts[label]
#         print(f"{dx:<8} {count:<10} {count/total*100:.1f}%")
#     print("=" * 55)
#     print(f"{'TOTAL':<8} {total}")

# %%
img_R, img_G, img_B, meta, labels = next(iter(train_loader))
print(img_R.shape)
print(meta.shape)
print(labels.shape)
print(labels[:10])
# Out:
# torch.Size([32, 1, 300, 300])
# torch.Size([32, 19])
# torch.Size([32])
# tensor([1, 1, 1, 1, 0, 2, 3, 3, 1, 1])

# %%
from PIL import Image

# label names for display
label_names = {
    0: 'bcc',
    1: 'bkl',
    2: 'mel',
    3: 'nv'
}

minority_class_ids = {0, 1, 2}
minority_aug_prob = 0.7

def denormalize(img_tensor, mean=0.449, std=0.226):
    img = img_tensor.clone().detach().cpu().numpy().squeeze()
    # (1,H,W) → (H,W) ← squeeze() remove dimension = 1
    img = img * std + mean
    img = np.clip(img, 0, 1)
    return img

def show_augmentation_example(df, index=None, n_aug=3):
    if index is None:
        index = np.random.randint(0, len(df))

    row = df.iloc[index]
    img_path = row['image_path_cleaned']
    label = int(row['label'])

    image = Image.open(img_path).convert("L")

    plt.figure(figsize=(4 * (n_aug + 1), 4))

    # original image
    plt.subplot(1, n_aug + 1, 1)
    plt.imshow(image, cmap='gray')
    plt.title(f"Original\n{label_names[label]}")
    plt.axis("off")

    # augmented versions
    for i in range(n_aug):
        if label in minority_class_ids and random.random() < minority_aug_prob:
            transform = train_transform_minority
            transform_name = "Minority Transform"
        else:
            transform = train_transform_base
            transform_name = "Base Transform"

        aug_tensor = transform(image)
        aug_img = denormalize(aug_tensor)

        plt.subplot(1, n_aug + 1, i + 2)
        plt.imshow(aug_img, cmap='gray')
        plt.title(f"{transform_name}\nAug {i+1}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# %%
fold_idx, train_df, val_df = folds[0]

# %%
show_augmentation_example(train_df, n_aug=4)

# %%
minority_df = train_df[train_df['label'].isin(minority_class_ids)].reset_index(drop=True)
show_augmentation_example(minority_df, n_aug=4)

# %%
majority_df = train_df[~train_df['label'].isin(minority_class_ids)].reset_index(drop=True)
show_augmentation_example(majority_df, n_aug=4)

# %%
from sklearn.metrics import accuracy_score, balanced_accuracy_score, f1_score

# %%
batch = next(iter(train_loader))
img_R, img_G, img_B, metadata, labels = batch

print("images shape   :", img_R.shape)
print("metadata shape :", metadata.shape)
print("labels shape   :", labels.shape)
print("labels dtype   :", labels.dtype)
print("unique labels  :", torch.unique(labels))
# Out:
# images shape   : torch.Size([32, 1, 300, 300])
# metadata shape : torch.Size([32, 19])
# labels shape   : torch.Size([32])
# labels dtype   : torch.int64
# unique labels  : tensor([0, 1, 2, 3])

# %%
def make_single_channel_efficientnet(pretrained=True):
    weights = EfficientNet_B0_Weights.DEFAULT if pretrained else None
    backbone = models.efficientnet_b0(weights=weights)

    # First conv of EfficientNet-B0: Conv2d(3, 32, kernel_size=3, stride=2)
    old_conv = backbone.features[0][0]  # Original Conv2d(3, 32, ...)

    # Creating a new conv will get 1 channel instead of 3.
    new_conv = nn.Conv2d(
        in_channels=1,          # Change from 3 to 1
        out_channels=old_conv.out_channels,   # 32
        kernel_size=old_conv.kernel_size,
        stride=old_conv.stride,
        padding=old_conv.padding,
        bias=old_conv.bias is not None
    )

    # Initialize weights: average the 3 original channels into 1.
    # Retain pretrained knowledge instead of random init
    with torch.no_grad():
        new_conv.weight = nn.Parameter(
            old_conv.weight.mean(dim=1, keepdim=True)  # (32,3,3,3) → (32,1,3,3)
        )

    # Replace first conv
    backbone.features[0][0] = new_conv

    return backbone.features  # only get feature extractor

# %%
class MultiModalSkinNet(nn.Module):
    def __init__(self, metadata_dim, num_classes=4, pretrained=True,
                 freeze_backbone=True, unfreeze_last_n_blocks=2):
        super().__init__()

        # 1 backbone only
        self.shared_backbone = make_single_channel_efficientnet(pretrained)
        self.pool = nn.AdaptiveAvgPool2d((1, 1))

        # Freeze/unfreeze
        if freeze_backbone:
            for param in self.shared_backbone.parameters():
                param.requires_grad = False
            # Unfreeze N last blocks
            blocks = list(self.shared_backbone.children())
            for block in blocks[-unfreeze_last_n_blocks:]:
                for param in block.parameters():
                    param.requires_grad = True

        image_feature_dim = 1280        # EfficientNet-B0 output
        fused_image_dim = image_feature_dim * 3  # 3 extraction times → 3840

        ### Add Dropout
        self.img_dropout = nn.Dropout(0.5)
        ###

        # Metadata branch
        self.metadata_branch = nn.Sequential(
            nn.Linear(metadata_dim, 64),
            nn.LayerNorm(64),
            nn.ReLU(),
            nn.Dropout(0.4), #at first it is 0.3
            nn.Linear(64, 32),
            nn.ReLU()
        )

        # Fusion classifier
        # EfficientNet-B0 - 1280 output features from one image
        # Classifier receives 3840 + 32
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(fused_image_dim + 32, 256),
            nn.ReLU(),
            nn.Dropout(0.5), #at first is 0.4
            nn.Linear(256, num_classes)
        )

    def extract(self, img):
        """Extract feature from 1 grayscale image"""
        return torch.flatten(self.pool(self.shared_backbone(img)), 1)

    def forward(self, img_R, img_G, img_B, metadata):
        feat_R = self.extract(img_R)  # (B, 1280)
        feat_G = self.extract(img_G)  # (B, 1280)
        feat_B = self.extract(img_B)  # (B, 1280)

        img_feat = torch.cat([feat_R, feat_G, feat_B], dim=1)  # (B, 3840)

        # ====== Add dropout ======
        img_feat = self.img_dropout(img_feat)
        # ============================

        meta_feat = self.metadata_branch(metadata)
        fused = torch.cat([img_feat, meta_feat], dim=1)
        return self.classifier(fused)

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()

    running_loss = 0.0
    all_preds = []
    all_labels = []

    for img_R, img_G, img_B, metadata, labels in loader:
        img_R = img_R.to(device)
        img_G = img_G.to(device)
        img_B = img_B.to(device)
        metadata = metadata.to(device).float()
        labels = labels.to(device).long()

        optimizer.zero_grad()

        outputs = model(img_R, img_G, img_B, metadata)
        loss = criterion(outputs, labels)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        running_loss += loss.item() * img_R.size(0)  # change images → img_R

        # img_R = img_G = img_B

        preds = torch.argmax(outputs, dim=1)
        all_preds.extend(preds.detach().cpu().numpy())
        all_labels.extend(labels.detach().cpu().numpy())

    epoch_loss = running_loss / len(loader.dataset)
    epoch_acc = accuracy_score(all_labels, all_preds)
    epoch_bal_acc = balanced_accuracy_score(all_labels, all_preds)
    epoch_f1 = f1_score(all_labels, all_preds, average="macro")

    return epoch_loss, epoch_acc, epoch_bal_acc, epoch_f1

# %%
def validate_one_epoch(model, loader, criterion, device):
    model.eval()

    running_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for img_R, img_G, img_B, metadata, labels in loader:
            img_R = img_R.to(device)
            img_G = img_G.to(device)
            img_B = img_B.to(device)
            metadata = metadata.to(device).float()
            labels = labels.to(device).long()

            outputs = model(img_R, img_G, img_B, metadata)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * img_R.size(0)  # change images → img_R

            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.detach().cpu().numpy())
            all_labels.extend(labels.detach().cpu().numpy())

    epoch_loss = running_loss / len(loader.dataset)
    epoch_acc = accuracy_score(all_labels, all_preds)
    epoch_bal_acc = balanced_accuracy_score(all_labels, all_preds)
    epoch_f1 = f1_score(all_labels, all_preds, average="macro")

    return epoch_loss, epoch_acc, epoch_bal_acc, epoch_f1

# %%
num_classes = int(skinDf['label'].nunique())
# num_epochs = 30
fold_results = []

all_fold_train_losses = []
all_fold_val_losses = []

all_fold_train_accs = []
all_fold_val_accs = []

all_fold_train_bal_accs = []
all_fold_val_bal_accs = []

all_fold_train_f1s = []
all_fold_val_f1s = []

for fold_idx, train_fold_df, val_fold_df in folds:
    print(f"\n{'='*60}")
    print(f"Starting Fold {fold_idx+1}/{len(folds)}")
    print(f"{'='*60}")

    train_loader, val_loader, metadata_dim = build_loaders_for_fold(
        train_fold_df, val_fold_df, batch_size=32
    )

    X_train_meta, X_val_meta, y_train, y_val, encoder, scaler = preprocess_metadata_per_fold(
        train_fold_df, val_fold_df
    )

    criterion = nn.CrossEntropyLoss()

    # ======================================================
    # Freeze the entire backbone, only train the head.
    # ======================================================
    print("\n--- Phase 1: Training head only (5 epochs) ---")

    model = MultiModalSkinNet(
        metadata_dim=metadata_dim,
        num_classes=num_classes,
        freeze_backbone=True,
        unfreeze_last_n_blocks=0    # freeze TOTAL backbone
    ).to(device)

    head_params = (
        list(model.metadata_branch.parameters()) +
        list(model.classifier.parameters())
    )
    optimizer_p1 = optim.Adam(head_params, lr=1e-4)

    for epoch in range(5):
        train_loss, train_acc, train_bal_acc, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer_p1, device
        )
        val_loss, val_acc, val_bal_acc, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )
        print(
            f"  [P1] Epoch {epoch+1}/5 | "
            f"Train F1: {train_f1:.4f} | Val F1: {val_f1:.4f}"
        )

    # ======================================================
    # Unfreeze the last 2 blocks, fine-tune everything
    # ======================================================
    print("\n--- Phase 2: Fine-tuning last 2 blocks (50 epochs) ---")

    # Unfreeze 2 last blocks of backbone
    blocks = list(model.shared_backbone.children())
    for block in blocks[-2:]:
        for param in block.parameters():
            param.requires_grad = True

    # Separate the parameters with different lr values.
    backbone_params = [
        p for p in model.shared_backbone.parameters()
        if p.requires_grad
    ]
    head_params = (
        list(model.metadata_branch.parameters()) +
        list(model.classifier.parameters())
    )

    optimizer_p2 = optim.AdamW([
        {"params": backbone_params, "lr": 3e-5},  # 1e-5 → 3e-5
        {"params": head_params,     "lr": 1e-4},
    ], weight_decay=2e-4, betas=(0.9, 0.999))    # 5e-4 → 1e-4

    scheduler = CosineAnnealingWarmRestarts(
        optimizer_p2, T_0=10, T_mult=2, eta_min=1e-7
    )

    # Early stopping settings
    patience = 9
    min_delta = 0.001
    best_val_f1 = -float("inf")
    best_epoch = -1
    epochs_without_improvement = 0
    best_model_state = None

    fold_train_losses = []
    fold_val_losses = []
    fold_train_accs = []
    fold_val_accs = []
    fold_train_bal_accs = []
    fold_val_bal_accs = []
    fold_train_f1s = []
    fold_val_f1s = []

    for epoch in range(50):
        train_loss, train_acc, train_bal_acc, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer_p2, device
        )
        val_loss, val_acc, val_bal_acc, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        scheduler.step()   # ← decrease lr when plateauing

        # Add log
        backbone_lr = optimizer_p2.param_groups[0]['lr']
        head_lr = optimizer_p2.param_groups[1]['lr']

        #

        fold_train_losses.append(train_loss)
        fold_train_accs.append(train_acc)
        fold_train_bal_accs.append(train_bal_acc)
        fold_train_f1s.append(train_f1)
        fold_val_losses.append(val_loss)
        fold_val_accs.append(val_acc)
        fold_val_bal_accs.append(val_bal_acc)
        fold_val_f1s.append(val_f1)

        print(
            f"Epoch [{epoch+1}/50] | "
            f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | "
            f"Train Bal Acc: {train_bal_acc:.4f} | Train Macro F1: {train_f1:.4f} || "
            f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f} | "
            f"Val Bal Acc: {val_bal_acc:.4f} | Val Macro F1: {val_f1:.4f} | "
            f"LR: backbone={backbone_lr:.2e}, head={head_lr:.2e}"
        )

        # Early stopping
        if val_f1 > best_val_f1 + min_delta:
            best_val_f1 = val_f1
            best_epoch = epoch
            epochs_without_improvement = 0
            best_model_state = copy.deepcopy(model.state_dict())
            print(f"  -> New best val_macro_f1: {best_val_f1:.4f}")
        else:
            epochs_without_improvement += 1
            print(f"  -> No improvement for {epochs_without_improvement}/{patience} epoch(s)")

        if epochs_without_improvement >= patience:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    # Restore best weights
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

    # Save PREPROCESSING OBJECTS
    preprocessing_data = {
        'encoder': encoder,
        'scaler': scaler,
        'metadata_dim': metadata_dim,
        'age_mean': train_fold_df['age'].mean()
    }
    preprocessing_path = f'preprocessing_fold_{fold_idx+1}.pkl'
    with open(preprocessing_path, 'wb') as f:
        pickle.dump(preprocessing_data, f)
    print(f"\n Saved preprocessing objects to: {preprocessing_path}")


    # FULL CHECKPOINT (THAY THẾ DÒNG CŨ)
    checkpoint = {
        'model_state_dict': best_model_state,
        'metadata_dim': metadata_dim,
        'num_classes': num_classes,
        'best_epoch': best_epoch + 1,  # +1 because epoch starts from 0
        'best_val_f1': best_val_f1,
        'best_val_acc': fold_val_accs[best_epoch],
        'best_val_bal_acc': fold_val_bal_accs[best_epoch],
        'best_val_loss': fold_val_losses[best_epoch],
        'fold': fold_idx + 1
    }
    checkpoint_path = f'checkpoint_fold_{fold_idx+1}.pth'
    torch.save(checkpoint, checkpoint_path)
    print(f"Saved full checkpoint to: {checkpoint_path}")



    # Still keep simple FILE WEIGHTS (OPTIONAL)
    weights_path = f'best_model_fold_{fold_idx+1}.pth'
    torch.save(best_model_state, weights_path)
    print(f" Saved model weights to: {weights_path}")


    fold_results.append({
        "fold": fold_idx + 1,
        "train_losses": fold_train_losses,
        "val_losses": fold_val_losses,
        "train_accs": fold_train_accs,
        "val_accs": fold_val_accs,
        "train_bal_accs": fold_train_bal_accs,
        "val_bal_accs": fold_val_bal_accs,
        "train_f1s": fold_train_f1s,
        "val_f1s": fold_val_f1s,
        "stopped_epoch": len(fold_val_f1s),
        "best_epoch": best_epoch + 1,
        "final_val_loss": fold_val_losses[-1],
        "final_val_acc": fold_val_accs[-1],
        "final_val_bal_acc": fold_val_bal_accs[-1],
        "final_val_f1": fold_val_f1s[-1],
        "best_val_loss": fold_val_losses[best_epoch],
        "best_val_acc": fold_val_accs[best_epoch],
        "best_val_bal_acc": fold_val_bal_accs[best_epoch],
        "best_val_f1": fold_val_f1s[best_epoch]
    })

    all_fold_train_losses.append(fold_train_losses)
    all_fold_val_losses.append(fold_val_losses)
    all_fold_train_accs.append(fold_train_accs)
    all_fold_val_accs.append(fold_val_accs)
    all_fold_train_bal_accs.append(fold_train_bal_accs)
    all_fold_val_bal_accs.append(fold_val_bal_accs)
    all_fold_train_f1s.append(fold_train_f1s)
    all_fold_val_f1s.append(fold_val_f1s)
# Out:
# ============================================================
# Starting Fold 1/5
# ============================================================
#
# --- Phase 1: Training head only (5 epochs) ---
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 185MB/s]
#   [P1] Epoch 1/5 | Train F1: 0.5056 | Val F1: 0.5696
#   [P1] Epoch 2/5 | Train F1: 0.6009 | Val F1: 0.5995
#   [P1] Epoch 3/5 | Train F1: 0.6347 | Val F1: 0.6341
#   [P1] Epoch 4/5 | Train F1: 0.6432 | Val F1: 0.6531
#   [P1] Epoch 5/5 | Train F1: 0.6585 | Val F1: 0.6653
#
# --- Phase 2: Fine-tuning last 2 blocks (50 epochs) ---
# Epoch [1/50] | Train Loss: 0.7415 | Train Acc: 0.6971 | Train Bal Acc: 0.6947 | Train Macro F1: 0.6922 || Val Loss: 0.5307 | Val Acc: 0.7866 | Val Bal Acc: 0.7328 | Val Macro F1: 0.6740 | LR: backbone=2.93e-05, head=9.76e-05
#   -> New best val_macro_f1: 0.6740
# Epoch [2/50] | Train Loss: 0.6552 | Train Acc: 0.7340 | Train Bal Acc: 0.7355 | Train Macro F1: 0.7341 || Val Loss: 0.4765 | Val Acc: 0.8007 | Val Bal Acc: 0.7153 | Val Macro F1: 0.6840 | LR: backbone=2.71e-05, head=9.05e-05
#   -> New best val_macro_f1: 0.6840
# Epoch [3/50] | Train Loss: 0.5964 | Train Acc: 0.7627 | Train Bal Acc: 0.7625 | Train Macro F1: 0.7613 || Val Loss: 0.4571 | Val Acc: 0.8164 | Val Bal Acc: 0.7220 | Val Macro F1: 0.6980 | LR: backbone=2.38e-05, head=7.94e-05
#   -> New best val_macro_f1: 0.6980
# Epoch [4/50] | Train Loss: 0.5377 | Train Acc: 0.7857 | Train Bal Acc: 0.7854 | Train Macro F1: 0.7845 || Val Loss: 0.4579 | Val Acc: 0.8202 | Val Bal Acc: 0.7343 | Val Macro F1: 0.7023 | LR: backbone=1.97e-05, head=6.55e-05
#   -> New best val_macro_f1: 0.7023
# Epoch [5/50] | Train Loss: 0.5231 | Train Acc: 0.7947 | Train Bal Acc: 0.7944 | Train Macro F1: 0.7934 || Val Loss: 0.4411 | Val Acc: 0.8256 | Val Bal Acc: 0.7427 | Val Macro F1: 0.7205 | LR: backbone=1.51e-05, head=5.01e-05
#   -> New best val_macro_f1: 0.7205
# Epoch [6/50] | Train Loss: 0.4921 | Train Acc: 0.8018 | Train Bal Acc: 0.8027 | Train Macro F1: 0.8016 || Val Loss: 0.4474 | Val Acc: 0.8250 | Val Bal Acc: 0.7415 | Val Macro F1: 0.7151 | LR: backbone=1.04e-05, head=3.46e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [7/50] | Train Loss: 0.4708 | Train Acc: 0.8100 | Train Bal Acc: 0.8093 | Train Macro F1: 0.8089 || Val Loss: 0.4330 | Val Acc: 0.8267 | Val Bal Acc: 0.7329 | Val Macro F1: 0.7175 | LR: backbone=6.26e-06, head=2.07e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [8/50] | Train Loss: 0.4609 | Train Acc: 0.8149 | Train Bal Acc: 0.8158 | Train Macro F1: 0.8149 || Val Loss: 0.4297 | Val Acc: 0.8332 | Val Bal Acc: 0.7333 | Val Macro F1: 0.7187 | LR: backbone=2.96e-06, head=9.64e-06
#   -> No improvement for 3/9 epoch(s)
# Epoch [9/50] | Train Loss: 0.4501 | Train Acc: 0.8203 | Train Bal Acc: 0.8208 | Train Macro F1: 0.8201 || Val Loss: 0.4155 | Val Acc: 0.8424 | Val Bal Acc: 0.7132 | Val Macro F1: 0.7193 | LR: backbone=8.32e-07, head=2.54e-06
#   -> No improvement for 4/9 epoch(s)
# Epoch [10/50] | Train Loss: 0.4572 | Train Acc: 0.8194 | Train Bal Acc: 0.8184 | Train Macro F1: 0.8181 || Val Loss: 0.4350 | Val Acc: 0.8261 | Val Bal Acc: 0.7253 | Val Macro F1: 0.7184 | LR: backbone=3.00e-05, head=1.00e-04
#   -> No improvement for 5/9 epoch(s)
# Epoch [11/50] | Train Loss: 0.4446 | Train Acc: 0.8278 | Train Bal Acc: 0.8278 | Train Macro F1: 0.8271 || Val Loss: 0.4279 | Val Acc: 0.8337 | Val Bal Acc: 0.7424 | Val Macro F1: 0.7226 | LR: backbone=2.98e-05, head=9.94e-05
#   -> New best val_macro_f1: 0.7226
# Epoch [12/50] | Train Loss: 0.4088 | Train Acc: 0.8391 | Train Bal Acc: 0.8378 | Train Macro F1: 0.8374 || Val Loss: 0.4135 | Val Acc: 0.8462 | Val Bal Acc: 0.7268 | Val Macro F1: 0.7301 | LR: backbone=2.93e-05, head=9.76e-05
#   -> New best val_macro_f1: 0.7301
# Epoch [13/50] | Train Loss: 0.3709 | Train Acc: 0.8523 | Train Bal Acc: 0.8519 | Train Macro F1: 0.8514 || Val Loss: 0.4253 | Val Acc: 0.8391 | Val Bal Acc: 0.7438 | Val Macro F1: 0.7283 | LR: backbone=2.84e-05, head=9.46e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [14/50] | Train Loss: 0.3714 | Train Acc: 0.8538 | Train Bal Acc: 0.8540 | Train Macro F1: 0.8534 || Val Loss: 0.4235 | Val Acc: 0.8462 | Val Bal Acc: 0.7386 | Val Macro F1: 0.7330 | LR: backbone=2.71e-05, head=9.05e-05
#   -> New best val_macro_f1: 0.7330
# Epoch [15/50] | Train Loss: 0.3465 | Train Acc: 0.8662 | Train Bal Acc: 0.8658 | Train Macro F1: 0.8657 || Val Loss: 0.4304 | Val Acc: 0.8472 | Val Bal Acc: 0.7362 | Val Macro F1: 0.7419 | LR: backbone=2.56e-05, head=8.54e-05
#   -> New best val_macro_f1: 0.7419
# Epoch [16/50] | Train Loss: 0.3070 | Train Acc: 0.8809 | Train Bal Acc: 0.8801 | Train Macro F1: 0.8799 || Val Loss: 0.4614 | Val Acc: 0.8434 | Val Bal Acc: 0.7208 | Val Macro F1: 0.7306 | LR: backbone=2.38e-05, head=7.94e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [17/50] | Train Loss: 0.3157 | Train Acc: 0.8801 | Train Bal Acc: 0.8813 | Train Macro F1: 0.8808 || Val Loss: 0.4351 | Val Acc: 0.8516 | Val Bal Acc: 0.7230 | Val Macro F1: 0.7394 | LR: backbone=2.18e-05, head=7.27e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [18/50] | Train Loss: 0.3048 | Train Acc: 0.8795 | Train Bal Acc: 0.8800 | Train Macro F1: 0.8796 || Val Loss: 0.4226 | Val Acc: 0.8510 | Val Bal Acc: 0.7202 | Val Macro F1: 0.7357 | LR: backbone=1.97e-05, head=6.55e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [19/50] | Train Loss: 0.2735 | Train Acc: 0.8927 | Train Bal Acc: 0.8927 | Train Macro F1: 0.8926 || Val Loss: 0.4611 | Val Acc: 0.8462 | Val Bal Acc: 0.7464 | Val Macro F1: 0.7412 | LR: backbone=1.74e-05, head=5.79e-05
#   -> No improvement for 4/9 epoch(s)
# Epoch [20/50] | Train Loss: 0.2933 | Train Acc: 0.8891 | Train Bal Acc: 0.8894 | Train Macro F1: 0.8890 || Val Loss: 0.4604 | Val Acc: 0.8456 | Val Bal Acc: 0.7492 | Val Macro F1: 0.7442 | LR: backbone=1.51e-05, head=5.01e-05
#   -> New best val_macro_f1: 0.7442
# Epoch [21/50] | Train Loss: 0.2636 | Train Acc: 0.8977 | Train Bal Acc: 0.8977 | Train Macro F1: 0.8974 || Val Loss: 0.4368 | Val Acc: 0.8559 | Val Bal Acc: 0.7446 | Val Macro F1: 0.7540 | LR: backbone=1.27e-05, head=4.22e-05
#   -> New best val_macro_f1: 0.7540
# Epoch [22/50] | Train Loss: 0.2527 | Train Acc: 0.9002 | Train Bal Acc: 0.8998 | Train Macro F1: 0.8996 || Val Loss: 0.4765 | Val Acc: 0.8527 | Val Bal Acc: 0.7266 | Val Macro F1: 0.7478 | LR: backbone=1.04e-05, head=3.46e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [23/50] | Train Loss: 0.2335 | Train Acc: 0.9098 | Train Bal Acc: 0.9097 | Train Macro F1: 0.9097 || Val Loss: 0.4767 | Val Acc: 0.8564 | Val Bal Acc: 0.7291 | Val Macro F1: 0.7483 | LR: backbone=8.26e-06, head=2.74e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [24/50] | Train Loss: 0.2464 | Train Acc: 0.9033 | Train Bal Acc: 0.9031 | Train Macro F1: 0.9029 || Val Loss: 0.4610 | Val Acc: 0.8548 | Val Bal Acc: 0.7482 | Val Macro F1: 0.7523 | LR: backbone=6.26e-06, head=2.07e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [25/50] | Train Loss: 0.2265 | Train Acc: 0.9119 | Train Bal Acc: 0.9116 | Train Macro F1: 0.9116 || Val Loss: 0.4595 | Val Acc: 0.8592 | Val Bal Acc: 0.7549 | Val Macro F1: 0.7545 | LR: backbone=4.48e-06, head=1.47e-05
#   -> No improvement for 4/9 epoch(s)
# Epoch [26/50] | Train Loss: 0.2313 | Train Acc: 0.9102 | Train Bal Acc: 0.9103 | Train Macro F1: 0.9101 || Val Loss: 0.4707 | Val Acc: 0.8516 | Val Bal Acc: 0.7323 | Val Macro F1: 0.7397 | LR: backbone=2.96e-06, head=9.64e-06
#   -> No improvement for 5/9 epoch(s)
# Epoch [27/50] | Train Loss: 0.2336 | Train Acc: 0.9111 | Train Bal Acc: 0.9109 | Train Macro F1: 0.9108 || Val Loss: 0.4730 | Val Acc: 0.8516 | Val Bal Acc: 0.7594 | Val Macro F1: 0.7498 | LR: backbone=1.73e-06, head=5.54e-06
#   -> No improvement for 6/9 epoch(s)
# Epoch [28/50] | Train Loss: 0.2077 | Train Acc: 0.9226 | Train Bal Acc: 0.9220 | Train Macro F1: 0.9219 || Val Loss: 0.4772 | Val Acc: 0.8521 | Val Bal Acc: 0.7139 | Val Macro F1: 0.7416 | LR: backbone=8.32e-07, head=2.54e-06
#   -> No improvement for 7/9 epoch(s)
# Epoch [29/50] | Train Loss: 0.2187 | Train Acc: 0.9146 | Train Bal Acc: 0.9144 | Train Macro F1: 0.9141 || Val Loss: 0.4728 | Val Acc: 0.8559 | Val Bal Acc: 0.7403 | Val Macro F1: 0.7565 | LR: backbone=2.84e-07, head=7.15e-07
#   -> New best val_macro_f1: 0.7565
# Epoch [30/50] | Train Loss: 0.2089 | Train Acc: 0.9184 | Train Bal Acc: 0.9180 | Train Macro F1: 0.9180 || Val Loss: 0.4909 | Val Acc: 0.8494 | Val Bal Acc: 0.7179 | Val Macro F1: 0.7367 | LR: backbone=3.00e-05, head=1.00e-04
#   -> No improvement for 1/9 epoch(s)
# Epoch [31/50] | Train Loss: 0.2353 | Train Acc: 0.9099 | Train Bal Acc: 0.9101 | Train Macro F1: 0.9100 || Val Loss: 0.4703 | Val Acc: 0.8505 | Val Bal Acc: 0.7386 | Val Macro F1: 0.7388 | LR: backbone=3.00e-05, head=9.98e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [32/50] | Train Loss: 0.2103 | Train Acc: 0.9209 | Train Bal Acc: 0.9212 | Train Macro F1: 0.9210 || Val Loss: 0.5345 | Val Acc: 0.8483 | Val Bal Acc: 0.7074 | Val Macro F1: 0.7267 | LR: backbone=2.98e-05, head=9.94e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [33/50] | Train Loss: 0.2013 | Train Acc: 0.9215 | Train Bal Acc: 0.9212 | Train Macro F1: 0.9212 || Val Loss: 0.5841 | Val Acc: 0.8505 | Val Bal Acc: 0.7437 | Val Macro F1: 0.7511 | LR: backbone=2.96e-05, head=9.86e-05
#   -> No improvement for 4/9 epoch(s)
# Epoch [34/50] | Train Loss: 0.1939 | Train Acc: 0.9295 | Train Bal Acc: 0.9290 | Train Macro F1: 0.9290 || Val Loss: 0.5711 | Val Acc: 0.8494 | Val Bal Acc: 0.7287 | Val Macro F1: 0.7441 | LR: backbone=2.93e-05, head=9.76e-05
#   -> No improvement for 5/9 epoch(s)
# Epoch [35/50] | Train Loss: 0.1841 | Train Acc: 0.9301 | Train Bal Acc: 0.9301 | Train Macro F1: 0.9301 || Val Loss: 0.5504 | Val Acc: 0.8510 | Val Bal Acc: 0.7471 | Val Macro F1: 0.7488 | LR: backbone=2.89e-05, head=9.62e-05
#   -> No improvement for 6/9 epoch(s)
# Epoch [36/50] | Train Loss: 0.1911 | Train Acc: 0.9256 | Train Bal Acc: 0.9263 | Train Macro F1: 0.9261 || Val Loss: 0.5542 | Val Acc: 0.8586 | Val Bal Acc: 0.7129 | Val Macro F1: 0.7444 | LR: backbone=2.84e-05, head=9.46e-05
#   -> No improvement for 7/9 epoch(s)
# Epoch [37/50] | Train Loss: 0.1806 | Train Acc: 0.9289 | Train Bal Acc: 0.9297 | Train Macro F1: 0.9294 || Val Loss: 0.5900 | Val Acc: 0.8597 | Val Bal Acc: 0.6932 | Val Macro F1: 0.7402 | LR: backbone=2.78e-05, head=9.26e-05
#   -> No improvement for 8/9 epoch(s)
# Epoch [38/50] | Train Loss: 0.1774 | Train Acc: 0.9338 | Train Bal Acc: 0.9334 | Train Macro F1: 0.9336 || Val Loss: 0.5837 | Val Acc: 0.8575 | Val Bal Acc: 0.6859 | Val Macro F1: 0.7374 | LR: backbone=2.71e-05, head=9.05e-05
#   -> No improvement for 9/9 epoch(s)
# Early stopping triggered at epoch 38
#
#  Saved preprocessing objects to: preprocessing_fold_1.pkl
# Saved full checkpoint to: checkpoint_fold_1.pth
#  Saved model weights to: best_model_fold_1.pth
#
# ============================================================
# Starting Fold 2/5
# ============================================================
#
# --- Phase 1: Training head only (5 epochs) ---
#   [P1] Epoch 1/5 | Train F1: 0.4987 | Val F1: 0.5098
#   [P1] Epoch 2/5 | Train F1: 0.6017 | Val F1: 0.5674
#   [P1] Epoch 3/5 | Train F1: 0.6353 | Val F1: 0.6095
#   [P1] Epoch 4/5 | Train F1: 0.6540 | Val F1: 0.5933
#   [P1] Epoch 5/5 | Train F1: 0.6539 | Val F1: 0.6161
#
# --- Phase 2: Fine-tuning last 2 blocks (50 epochs) ---
# Epoch [1/50] | Train Loss: 0.7496 | Train Acc: 0.6939 | Train Bal Acc: 0.6914 | Train Macro F1: 0.6886 || Val Loss: 0.5322 | Val Acc: 0.8009 | Val Bal Acc: 0.6954 | Val Macro F1: 0.6595 | LR: backbone=2.93e-05, head=9.76e-05
#   -> New best val_macro_f1: 0.6595
# Epoch [2/50] | Train Loss: 0.6664 | Train Acc: 0.7282 | Train Bal Acc: 0.7297 | Train Macro F1: 0.7278 || Val Loss: 0.5350 | Val Acc: 0.7983 | Val Bal Acc: 0.7316 | Val Macro F1: 0.6754 | LR: backbone=2.71e-05, head=9.05e-05
#   -> New best val_macro_f1: 0.6754
# Epoch [3/50] | Train Loss: 0.6035 | Train Acc: 0.7616 | Train Bal Acc: 0.7615 | Train Macro F1: 0.7601 || Val Loss: 0.4992 | Val Acc: 0.8108 | Val Bal Acc: 0.7096 | Val Macro F1: 0.6717 | LR: backbone=2.38e-05, head=7.94e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [4/50] | Train Loss: 0.5434 | Train Acc: 0.7854 | Train Bal Acc: 0.7853 | Train Macro F1: 0.7838 || Val Loss: 0.5080 | Val Acc: 0.8004 | Val Bal Acc: 0.7133 | Val Macro F1: 0.6831 | LR: backbone=1.97e-05, head=6.55e-05
#   -> New best val_macro_f1: 0.6831
# Epoch [5/50] | Train Loss: 0.5049 | Train Acc: 0.7959 | Train Bal Acc: 0.7953 | Train Macro F1: 0.7944 || Val Loss: 0.4639 | Val Acc: 0.8259 | Val Bal Acc: 0.7294 | Val Macro F1: 0.7020 | LR: backbone=1.51e-05, head=5.01e-05
#   -> New best val_macro_f1: 0.7020
# Epoch [6/50] | Train Loss: 0.4842 | Train Acc: 0.8082 | Train Bal Acc: 0.8088 | Train Macro F1: 0.8079 || Val Loss: 0.4592 | Val Acc: 0.8217 | Val Bal Acc: 0.7131 | Val Macro F1: 0.6974 | LR: backbone=1.04e-05, head=3.46e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [7/50] | Train Loss: 0.4593 | Train Acc: 0.8202 | Train Bal Acc: 0.8205 | Train Macro F1: 0.8190 || Val Loss: 0.4584 | Val Acc: 0.8217 | Val Bal Acc: 0.7238 | Val Macro F1: 0.7013 | LR: backbone=6.26e-06, head=2.07e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [8/50] | Train Loss: 0.4482 | Train Acc: 0.8221 | Train Bal Acc: 0.8217 | Train Macro F1: 0.8210 || Val Loss: 0.4990 | Val Acc: 0.8113 | Val Bal Acc: 0.7237 | Val Macro F1: 0.6765 | LR: backbone=2.96e-06, head=9.64e-06
#   -> No improvement for 3/9 epoch(s)
# Epoch [9/50] | Train Loss: 0.4433 | Train Acc: 0.8293 | Train Bal Acc: 0.8310 | Train Macro F1: 0.8294 || Val Loss: 0.4586 | Val Acc: 0.8248 | Val Bal Acc: 0.7339 | Val Macro F1: 0.7088 | LR: backbone=8.32e-07, head=2.54e-06
#   -> New best val_macro_f1: 0.7088
# Epoch [10/50] | Train Loss: 0.4378 | Train Acc: 0.8248 | Train Bal Acc: 0.8233 | Train Macro F1: 0.8227 || Val Loss: 0.4626 | Val Acc: 0.8254 | Val Bal Acc: 0.7049 | Val Macro F1: 0.6970 | LR: backbone=3.00e-05, head=1.00e-04
#   -> No improvement for 1/9 epoch(s)
# Epoch [11/50] | Train Loss: 0.4286 | Train Acc: 0.8287 | Train Bal Acc: 0.8290 | Train Macro F1: 0.8281 || Val Loss: 0.4679 | Val Acc: 0.8243 | Val Bal Acc: 0.7440 | Val Macro F1: 0.7089 | LR: backbone=2.98e-05, head=9.94e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [12/50] | Train Loss: 0.3953 | Train Acc: 0.8428 | Train Bal Acc: 0.8421 | Train Macro F1: 0.8413 || Val Loss: 0.4595 | Val Acc: 0.8326 | Val Bal Acc: 0.7526 | Val Macro F1: 0.7220 | LR: backbone=2.93e-05, head=9.76e-05
#   -> New best val_macro_f1: 0.7220
# Epoch [13/50] | Train Loss: 0.3885 | Train Acc: 0.8456 | Train Bal Acc: 0.8449 | Train Macro F1: 0.8442 || Val Loss: 0.5154 | Val Acc: 0.8170 | Val Bal Acc: 0.7256 | Val Macro F1: 0.6904 | LR: backbone=2.84e-05, head=9.46e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [14/50] | Train Loss: 0.3590 | Train Acc: 0.8606 | Train Bal Acc: 0.8604 | Train Macro F1: 0.8598 || Val Loss: 0.4626 | Val Acc: 0.8358 | Val Bal Acc: 0.7384 | Val Macro F1: 0.7306 | LR: backbone=2.71e-05, head=9.05e-05
#   -> New best val_macro_f1: 0.7306
# Epoch [15/50] | Train Loss: 0.3511 | Train Acc: 0.8604 | Train Bal Acc: 0.8603 | Train Macro F1: 0.8595 || Val Loss: 0.4758 | Val Acc: 0.8358 | Val Bal Acc: 0.7251 | Val Macro F1: 0.7160 | LR: backbone=2.56e-05, head=8.54e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [16/50] | Train Loss: 0.3209 | Train Acc: 0.8782 | Train Bal Acc: 0.8775 | Train Macro F1: 0.8772 || Val Loss: 0.4953 | Val Acc: 0.8342 | Val Bal Acc: 0.7468 | Val Macro F1: 0.7267 | LR: backbone=2.38e-05, head=7.94e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [17/50] | Train Loss: 0.3138 | Train Acc: 0.8773 | Train Bal Acc: 0.8775 | Train Macro F1: 0.8769 || Val Loss: 0.5143 | Val Acc: 0.8150 | Val Bal Acc: 0.7243 | Val Macro F1: 0.6974 | LR: backbone=2.18e-05, head=7.27e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [18/50] | Train Loss: 0.2875 | Train Acc: 0.8900 | Train Bal Acc: 0.8909 | Train Macro F1: 0.8904 || Val Loss: 0.5160 | Val Acc: 0.8228 | Val Bal Acc: 0.7076 | Val Macro F1: 0.6984 | LR: backbone=1.97e-05, head=6.55e-05
#   -> No improvement for 4/9 epoch(s)
# Epoch [19/50] | Train Loss: 0.2836 | Train Acc: 0.8880 | Train Bal Acc: 0.8880 | Train Macro F1: 0.8878 || Val Loss: 0.5131 | Val Acc: 0.8295 | Val Bal Acc: 0.7029 | Val Macro F1: 0.7135 | LR: backbone=1.74e-05, head=5.79e-05
#   -> No improvement for 5/9 epoch(s)
# Epoch [20/50] | Train Loss: 0.2643 | Train Acc: 0.8970 | Train Bal Acc: 0.8972 | Train Macro F1: 0.8970 || Val Loss: 0.5123 | Val Acc: 0.8347 | Val Bal Acc: 0.7261 | Val Macro F1: 0.7184 | LR: backbone=1.51e-05, head=5.01e-05
#   -> No improvement for 6/9 epoch(s)
# Epoch [21/50] | Train Loss: 0.2574 | Train Acc: 0.9004 | Train Bal Acc: 0.9002 | Train Macro F1: 0.9000 || Val Loss: 0.4918 | Val Acc: 0.8337 | Val Bal Acc: 0.7322 | Val Macro F1: 0.7213 | LR: backbone=1.27e-05, head=4.22e-05
#   -> No improvement for 7/9 epoch(s)
# Epoch [22/50] | Train Loss: 0.2409 | Train Acc: 0.9067 | Train Bal Acc: 0.9067 | Train Macro F1: 0.9064 || Val Loss: 0.5197 | Val Acc: 0.8326 | Val Bal Acc: 0.7088 | Val Macro F1: 0.7128 | LR: backbone=1.04e-05, head=3.46e-05
#   -> No improvement for 8/9 epoch(s)
# Epoch [23/50] | Train Loss: 0.2332 | Train Acc: 0.9077 | Train Bal Acc: 0.9080 | Train Macro F1: 0.9078 || Val Loss: 0.5274 | Val Acc: 0.8373 | Val Bal Acc: 0.7373 | Val Macro F1: 0.7311 | LR: backbone=8.26e-06, head=2.74e-05
#   -> No improvement for 9/9 epoch(s)
# Early stopping triggered at epoch 23
#
#  Saved preprocessing objects to: preprocessing_fold_2.pkl
# Saved full checkpoint to: checkpoint_fold_2.pth
#  Saved model weights to: best_model_fold_2.pth
#
# ============================================================
# Starting Fold 3/5
# ============================================================
#
# --- Phase 1: Training head only (5 epochs) ---
#   [P1] Epoch 1/5 | Train F1: 0.5173 | Val F1: 0.4956
#   [P1] Epoch 2/5 | Train F1: 0.6249 | Val F1: 0.5557
#   [P1] Epoch 3/5 | Train F1: 0.6438 | Val F1: 0.5934
#   [P1] Epoch 4/5 | Train F1: 0.6638 | Val F1: 0.5977
#   [P1] Epoch 5/5 | Train F1: 0.6666 | Val F1: 0.5973
#
# --- Phase 2: Fine-tuning last 2 blocks (50 epochs) ---
# Epoch [1/50] | Train Loss: 0.7218 | Train Acc: 0.7101 | Train Bal Acc: 0.7075 | Train Macro F1: 0.7053 || Val Loss: 0.5523 | Val Acc: 0.7758 | Val Bal Acc: 0.6435 | Val Macro F1: 0.6319 | LR: backbone=2.93e-05, head=9.76e-05
#   -> New best val_macro_f1: 0.6319
# Epoch [2/50] | Train Loss: 0.6388 | Train Acc: 0.7408 | Train Bal Acc: 0.7423 | Train Macro F1: 0.7404 || Val Loss: 0.5509 | Val Acc: 0.7789 | Val Bal Acc: 0.7172 | Val Macro F1: 0.6672 | LR: backbone=2.71e-05, head=9.05e-05
#   -> New best val_macro_f1: 0.6672
# Epoch [3/50] | Train Loss: 0.5876 | Train Acc: 0.7656 | Train Bal Acc: 0.7654 | Train Macro F1: 0.7641 || Val Loss: 0.5042 | Val Acc: 0.8074 | Val Bal Acc: 0.7028 | Val Macro F1: 0.6860 | LR: backbone=2.38e-05, head=7.94e-05
#   -> New best val_macro_f1: 0.6860
# Epoch [4/50] | Train Loss: 0.5286 | Train Acc: 0.7896 | Train Bal Acc: 0.7892 | Train Macro F1: 0.7880 || Val Loss: 0.5289 | Val Acc: 0.7942 | Val Bal Acc: 0.6898 | Val Macro F1: 0.6744 | LR: backbone=1.97e-05, head=6.55e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [5/50] | Train Loss: 0.5033 | Train Acc: 0.8001 | Train Bal Acc: 0.7996 | Train Macro F1: 0.7989 || Val Loss: 0.4912 | Val Acc: 0.8211 | Val Bal Acc: 0.7262 | Val Macro F1: 0.7052 | LR: backbone=1.51e-05, head=5.01e-05
#   -> New best val_macro_f1: 0.7052
# Epoch [6/50] | Train Loss: 0.4685 | Train Acc: 0.8094 | Train Bal Acc: 0.8100 | Train Macro F1: 0.8087 || Val Loss: 0.5101 | Val Acc: 0.7974 | Val Bal Acc: 0.7181 | Val Macro F1: 0.6889 | LR: backbone=1.04e-05, head=3.46e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [7/50] | Train Loss: 0.4685 | Train Acc: 0.8144 | Train Bal Acc: 0.8148 | Train Macro F1: 0.8139 || Val Loss: 0.5004 | Val Acc: 0.8147 | Val Bal Acc: 0.7155 | Val Macro F1: 0.7055 | LR: backbone=6.26e-06, head=2.07e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [8/50] | Train Loss: 0.4316 | Train Acc: 0.8275 | Train Bal Acc: 0.8275 | Train Macro F1: 0.8267 || Val Loss: 0.4934 | Val Acc: 0.8105 | Val Bal Acc: 0.7356 | Val Macro F1: 0.7098 | LR: backbone=2.96e-06, head=9.64e-06
#   -> New best val_macro_f1: 0.7098
# Epoch [9/50] | Train Loss: 0.4354 | Train Acc: 0.8254 | Train Bal Acc: 0.8268 | Train Macro F1: 0.8252 || Val Loss: 0.5031 | Val Acc: 0.8042 | Val Bal Acc: 0.7411 | Val Macro F1: 0.7062 | LR: backbone=8.32e-07, head=2.54e-06
#   -> No improvement for 1/9 epoch(s)
# Epoch [10/50] | Train Loss: 0.4450 | Train Acc: 0.8222 | Train Bal Acc: 0.8208 | Train Macro F1: 0.8205 || Val Loss: 0.4808 | Val Acc: 0.8268 | Val Bal Acc: 0.7273 | Val Macro F1: 0.7215 | LR: backbone=3.00e-05, head=1.00e-04
#   -> New best val_macro_f1: 0.7215
# Epoch [11/50] | Train Loss: 0.4473 | Train Acc: 0.8207 | Train Bal Acc: 0.8212 | Train Macro F1: 0.8200 || Val Loss: 0.5238 | Val Acc: 0.8026 | Val Bal Acc: 0.7496 | Val Macro F1: 0.7162 | LR: backbone=2.98e-05, head=9.94e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [12/50] | Train Loss: 0.3986 | Train Acc: 0.8418 | Train Bal Acc: 0.8409 | Train Macro F1: 0.8405 || Val Loss: 0.5051 | Val Acc: 0.8163 | Val Bal Acc: 0.7205 | Val Macro F1: 0.7126 | LR: backbone=2.93e-05, head=9.76e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [13/50] | Train Loss: 0.3675 | Train Acc: 0.8540 | Train Bal Acc: 0.8530 | Train Macro F1: 0.8526 || Val Loss: 0.5180 | Val Acc: 0.8216 | Val Bal Acc: 0.7346 | Val Macro F1: 0.7216 | LR: backbone=2.84e-05, head=9.46e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [14/50] | Train Loss: 0.3398 | Train Acc: 0.8669 | Train Bal Acc: 0.8669 | Train Macro F1: 0.8663 || Val Loss: 0.5133 | Val Acc: 0.8300 | Val Bal Acc: 0.7598 | Val Macro F1: 0.7329 | LR: backbone=2.71e-05, head=9.05e-05
#   -> New best val_macro_f1: 0.7329
# Epoch [15/50] | Train Loss: 0.3413 | Train Acc: 0.8656 | Train Bal Acc: 0.8654 | Train Macro F1: 0.8648 || Val Loss: 0.5063 | Val Acc: 0.8316 | Val Bal Acc: 0.7230 | Val Macro F1: 0.7245 | LR: backbone=2.56e-05, head=8.54e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [16/50] | Train Loss: 0.3084 | Train Acc: 0.8767 | Train Bal Acc: 0.8756 | Train Macro F1: 0.8754 || Val Loss: 0.5464 | Val Acc: 0.8363 | Val Bal Acc: 0.7053 | Val Macro F1: 0.7213 | LR: backbone=2.38e-05, head=7.94e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [17/50] | Train Loss: 0.3046 | Train Acc: 0.8806 | Train Bal Acc: 0.8811 | Train Macro F1: 0.8807 || Val Loss: 0.5256 | Val Acc: 0.8405 | Val Bal Acc: 0.7342 | Val Macro F1: 0.7353 | LR: backbone=2.18e-05, head=7.27e-05
#   -> New best val_macro_f1: 0.7353
# Epoch [18/50] | Train Loss: 0.2911 | Train Acc: 0.8815 | Train Bal Acc: 0.8827 | Train Macro F1: 0.8824 || Val Loss: 0.5609 | Val Acc: 0.8321 | Val Bal Acc: 0.7105 | Val Macro F1: 0.7206 | LR: backbone=1.97e-05, head=6.55e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [19/50] | Train Loss: 0.2749 | Train Acc: 0.8932 | Train Bal Acc: 0.8927 | Train Macro F1: 0.8924 || Val Loss: 0.5434 | Val Acc: 0.8453 | Val Bal Acc: 0.7249 | Val Macro F1: 0.7389 | LR: backbone=1.74e-05, head=5.79e-05
#   -> New best val_macro_f1: 0.7389
# Epoch [20/50] | Train Loss: 0.2707 | Train Acc: 0.8932 | Train Bal Acc: 0.8938 | Train Macro F1: 0.8935 || Val Loss: 0.5656 | Val Acc: 0.8353 | Val Bal Acc: 0.7194 | Val Macro F1: 0.7240 | LR: backbone=1.51e-05, head=5.01e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [21/50] | Train Loss: 0.2490 | Train Acc: 0.9024 | Train Bal Acc: 0.9022 | Train Macro F1: 0.9020 || Val Loss: 0.5606 | Val Acc: 0.8321 | Val Bal Acc: 0.7416 | Val Macro F1: 0.7339 | LR: backbone=1.27e-05, head=4.22e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [22/50] | Train Loss: 0.2313 | Train Acc: 0.9097 | Train Bal Acc: 0.9099 | Train Macro F1: 0.9096 || Val Loss: 0.5945 | Val Acc: 0.8363 | Val Bal Acc: 0.7104 | Val Macro F1: 0.7230 | LR: backbone=1.04e-05, head=3.46e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [23/50] | Train Loss: 0.2301 | Train Acc: 0.9093 | Train Bal Acc: 0.9095 | Train Macro F1: 0.9093 || Val Loss: 0.6115 | Val Acc: 0.8321 | Val Bal Acc: 0.7146 | Val Macro F1: 0.7223 | LR: backbone=8.26e-06, head=2.74e-05
#   -> No improvement for 4/9 epoch(s)
# Epoch [24/50] | Train Loss: 0.2350 | Train Acc: 0.9097 | Train Bal Acc: 0.9091 | Train Macro F1: 0.9090 || Val Loss: 0.6100 | Val Acc: 0.8268 | Val Bal Acc: 0.7045 | Val Macro F1: 0.7116 | LR: backbone=6.26e-06, head=2.07e-05
#   -> No improvement for 5/9 epoch(s)
# Epoch [25/50] | Train Loss: 0.2301 | Train Acc: 0.9118 | Train Bal Acc: 0.9122 | Train Macro F1: 0.9117 || Val Loss: 0.5986 | Val Acc: 0.8321 | Val Bal Acc: 0.7018 | Val Macro F1: 0.7180 | LR: backbone=4.48e-06, head=1.47e-05
#   -> No improvement for 6/9 epoch(s)
# Epoch [26/50] | Train Loss: 0.2160 | Train Acc: 0.9149 | Train Bal Acc: 0.9149 | Train Macro F1: 0.9148 || Val Loss: 0.5824 | Val Acc: 0.8453 | Val Bal Acc: 0.7232 | Val Macro F1: 0.7378 | LR: backbone=2.96e-06, head=9.64e-06
#   -> No improvement for 7/9 epoch(s)
# Epoch [27/50] | Train Loss: 0.2192 | Train Acc: 0.9187 | Train Bal Acc: 0.9182 | Train Macro F1: 0.9182 || Val Loss: 0.5868 | Val Acc: 0.8337 | Val Bal Acc: 0.7250 | Val Macro F1: 0.7273 | LR: backbone=1.73e-06, head=5.54e-06
#   -> No improvement for 8/9 epoch(s)
# Epoch [28/50] | Train Loss: 0.2104 | Train Acc: 0.9180 | Train Bal Acc: 0.9174 | Train Macro F1: 0.9171 || Val Loss: 0.5977 | Val Acc: 0.8405 | Val Bal Acc: 0.7141 | Val Macro F1: 0.7294 | LR: backbone=8.32e-07, head=2.54e-06
#   -> No improvement for 9/9 epoch(s)
# Early stopping triggered at epoch 28
#
#  Saved preprocessing objects to: preprocessing_fold_3.pkl
# Saved full checkpoint to: checkpoint_fold_3.pth
#  Saved model weights to: best_model_fold_3.pth
#
# ============================================================
# Starting Fold 4/5
# ============================================================
#
# --- Phase 1: Training head only (5 epochs) ---
#   [P1] Epoch 1/5 | Train F1: 0.5073 | Val F1: 0.5547
#   [P1] Epoch 2/5 | Train F1: 0.5962 | Val F1: 0.6191
#   [P1] Epoch 3/5 | Train F1: 0.6310 | Val F1: 0.6523
#   [P1] Epoch 4/5 | Train F1: 0.6427 | Val F1: 0.6492
#   [P1] Epoch 5/5 | Train F1: 0.6520 | Val F1: 0.6460
#
# --- Phase 2: Fine-tuning last 2 blocks (50 epochs) ---
# Epoch [1/50] | Train Loss: 0.7330 | Train Acc: 0.6945 | Train Bal Acc: 0.6922 | Train Macro F1: 0.6903 || Val Loss: 0.5227 | Val Acc: 0.8012 | Val Bal Acc: 0.7403 | Val Macro F1: 0.6793 | LR: backbone=2.93e-05, head=9.76e-05
#   -> New best val_macro_f1: 0.6793
# Epoch [2/50] | Train Loss: 0.6441 | Train Acc: 0.7427 | Train Bal Acc: 0.7440 | Train Macro F1: 0.7425 || Val Loss: 0.4917 | Val Acc: 0.8060 | Val Bal Acc: 0.7443 | Val Macro F1: 0.6893 | LR: backbone=2.71e-05, head=9.05e-05
#   -> New best val_macro_f1: 0.6893
# Epoch [3/50] | Train Loss: 0.5849 | Train Acc: 0.7642 | Train Bal Acc: 0.7641 | Train Macro F1: 0.7631 || Val Loss: 0.4460 | Val Acc: 0.8322 | Val Bal Acc: 0.7456 | Val Macro F1: 0.7262 | LR: backbone=2.38e-05, head=7.94e-05
#   -> New best val_macro_f1: 0.7262
# Epoch [4/50] | Train Loss: 0.5439 | Train Acc: 0.7801 | Train Bal Acc: 0.7799 | Train Macro F1: 0.7786 || Val Loss: 0.4442 | Val Acc: 0.8381 | Val Bal Acc: 0.7573 | Val Macro F1: 0.7332 | LR: backbone=1.97e-05, head=6.55e-05
#   -> New best val_macro_f1: 0.7332
# Epoch [5/50] | Train Loss: 0.5203 | Train Acc: 0.7950 | Train Bal Acc: 0.7948 | Train Macro F1: 0.7941 || Val Loss: 0.4620 | Val Acc: 0.8332 | Val Bal Acc: 0.7629 | Val Macro F1: 0.7219 | LR: backbone=1.51e-05, head=5.01e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [6/50] | Train Loss: 0.4937 | Train Acc: 0.8043 | Train Bal Acc: 0.8048 | Train Macro F1: 0.8042 || Val Loss: 0.4182 | Val Acc: 0.8493 | Val Bal Acc: 0.7515 | Val Macro F1: 0.7348 | LR: backbone=1.04e-05, head=3.46e-05
#   -> New best val_macro_f1: 0.7348
# Epoch [7/50] | Train Loss: 0.4574 | Train Acc: 0.8170 | Train Bal Acc: 0.8171 | Train Macro F1: 0.8164 || Val Loss: 0.4845 | Val Acc: 0.8204 | Val Bal Acc: 0.7680 | Val Macro F1: 0.7213 | LR: backbone=6.26e-06, head=2.07e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [8/50] | Train Loss: 0.4626 | Train Acc: 0.8169 | Train Bal Acc: 0.8173 | Train Macro F1: 0.8165 || Val Loss: 0.4533 | Val Acc: 0.8466 | Val Bal Acc: 0.7606 | Val Macro F1: 0.7231 | LR: backbone=2.96e-06, head=9.64e-06
#   -> No improvement for 2/9 epoch(s)
# Epoch [9/50] | Train Loss: 0.4341 | Train Acc: 0.8318 | Train Bal Acc: 0.8331 | Train Macro F1: 0.8319 || Val Loss: 0.4379 | Val Acc: 0.8487 | Val Bal Acc: 0.7605 | Val Macro F1: 0.7395 | LR: backbone=8.32e-07, head=2.54e-06
#   -> New best val_macro_f1: 0.7395
# Epoch [10/50] | Train Loss: 0.4509 | Train Acc: 0.8199 | Train Bal Acc: 0.8186 | Train Macro F1: 0.8183 || Val Loss: 0.4452 | Val Acc: 0.8466 | Val Bal Acc: 0.7704 | Val Macro F1: 0.7372 | LR: backbone=3.00e-05, head=1.00e-04
#   -> No improvement for 1/9 epoch(s)
# Epoch [11/50] | Train Loss: 0.4308 | Train Acc: 0.8283 | Train Bal Acc: 0.8280 | Train Macro F1: 0.8274 || Val Loss: 0.4267 | Val Acc: 0.8530 | Val Bal Acc: 0.7668 | Val Macro F1: 0.7488 | LR: backbone=2.98e-05, head=9.94e-05
#   -> New best val_macro_f1: 0.7488
# Epoch [12/50] | Train Loss: 0.3884 | Train Acc: 0.8461 | Train Bal Acc: 0.8451 | Train Macro F1: 0.8447 || Val Loss: 0.4708 | Val Acc: 0.8434 | Val Bal Acc: 0.7361 | Val Macro F1: 0.7187 | LR: backbone=2.93e-05, head=9.76e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [13/50] | Train Loss: 0.3928 | Train Acc: 0.8427 | Train Bal Acc: 0.8422 | Train Macro F1: 0.8418 || Val Loss: 0.4260 | Val Acc: 0.8514 | Val Bal Acc: 0.7629 | Val Macro F1: 0.7441 | LR: backbone=2.84e-05, head=9.46e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [14/50] | Train Loss: 0.3589 | Train Acc: 0.8550 | Train Bal Acc: 0.8548 | Train Macro F1: 0.8540 || Val Loss: 0.4559 | Val Acc: 0.8520 | Val Bal Acc: 0.7481 | Val Macro F1: 0.7405 | LR: backbone=2.71e-05, head=9.05e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [15/50] | Train Loss: 0.3441 | Train Acc: 0.8664 | Train Bal Acc: 0.8664 | Train Macro F1: 0.8657 || Val Loss: 0.4329 | Val Acc: 0.8626 | Val Bal Acc: 0.7652 | Val Macro F1: 0.7607 | LR: backbone=2.56e-05, head=8.54e-05
#   -> New best val_macro_f1: 0.7607
# Epoch [16/50] | Train Loss: 0.3249 | Train Acc: 0.8730 | Train Bal Acc: 0.8717 | Train Macro F1: 0.8716 || Val Loss: 0.4480 | Val Acc: 0.8557 | Val Bal Acc: 0.7571 | Val Macro F1: 0.7497 | LR: backbone=2.38e-05, head=7.94e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [17/50] | Train Loss: 0.3033 | Train Acc: 0.8836 | Train Bal Acc: 0.8846 | Train Macro F1: 0.8840 || Val Loss: 0.4762 | Val Acc: 0.8493 | Val Bal Acc: 0.7561 | Val Macro F1: 0.7434 | LR: backbone=2.18e-05, head=7.27e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [18/50] | Train Loss: 0.3073 | Train Acc: 0.8775 | Train Bal Acc: 0.8781 | Train Macro F1: 0.8777 || Val Loss: 0.4912 | Val Acc: 0.8584 | Val Bal Acc: 0.7487 | Val Macro F1: 0.7508 | LR: backbone=1.97e-05, head=6.55e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [19/50] | Train Loss: 0.2923 | Train Acc: 0.8861 | Train Bal Acc: 0.8859 | Train Macro F1: 0.8857 || Val Loss: 0.4742 | Val Acc: 0.8520 | Val Bal Acc: 0.7702 | Val Macro F1: 0.7525 | LR: backbone=1.74e-05, head=5.79e-05
#   -> No improvement for 4/9 epoch(s)
# Epoch [20/50] | Train Loss: 0.2717 | Train Acc: 0.8931 | Train Bal Acc: 0.8935 | Train Macro F1: 0.8932 || Val Loss: 0.4852 | Val Acc: 0.8525 | Val Bal Acc: 0.7544 | Val Macro F1: 0.7452 | LR: backbone=1.51e-05, head=5.01e-05
#   -> No improvement for 5/9 epoch(s)
# Epoch [21/50] | Train Loss: 0.2507 | Train Acc: 0.9004 | Train Bal Acc: 0.9004 | Train Macro F1: 0.9004 || Val Loss: 0.5280 | Val Acc: 0.8509 | Val Bal Acc: 0.7398 | Val Macro F1: 0.7363 | LR: backbone=1.27e-05, head=4.22e-05
#   -> No improvement for 6/9 epoch(s)
# Epoch [22/50] | Train Loss: 0.2415 | Train Acc: 0.9074 | Train Bal Acc: 0.9074 | Train Macro F1: 0.9073 || Val Loss: 0.5013 | Val Acc: 0.8487 | Val Bal Acc: 0.7679 | Val Macro F1: 0.7521 | LR: backbone=1.04e-05, head=3.46e-05
#   -> No improvement for 7/9 epoch(s)
# Epoch [23/50] | Train Loss: 0.2417 | Train Acc: 0.9057 | Train Bal Acc: 0.9058 | Train Macro F1: 0.9057 || Val Loss: 0.4849 | Val Acc: 0.8568 | Val Bal Acc: 0.7659 | Val Macro F1: 0.7580 | LR: backbone=8.26e-06, head=2.74e-05
#   -> No improvement for 8/9 epoch(s)
# Epoch [24/50] | Train Loss: 0.2267 | Train Acc: 0.9125 | Train Bal Acc: 0.9119 | Train Macro F1: 0.9118 || Val Loss: 0.4944 | Val Acc: 0.8642 | Val Bal Acc: 0.7431 | Val Macro F1: 0.7524 | LR: backbone=6.26e-06, head=2.07e-05
#   -> No improvement for 9/9 epoch(s)
# Early stopping triggered at epoch 24
#
#  Saved preprocessing objects to: preprocessing_fold_4.pkl
# Saved full checkpoint to: checkpoint_fold_4.pth
#  Saved model weights to: best_model_fold_4.pth
#
# ============================================================
# Starting Fold 5/5
# ============================================================
#
# --- Phase 1: Training head only (5 epochs) ---
#   [P1] Epoch 1/5 | Train F1: 0.4951 | Val F1: 0.5163
#   [P1] Epoch 2/5 | Train F1: 0.5974 | Val F1: 0.5892
#   [P1] Epoch 3/5 | Train F1: 0.6294 | Val F1: 0.6326
#   [P1] Epoch 4/5 | Train F1: 0.6509 | Val F1: 0.6341
#   [P1] Epoch 5/5 | Train F1: 0.6510 | Val F1: 0.6416
#
# --- Phase 2: Fine-tuning last 2 blocks (50 epochs) ---
# Epoch [1/50] | Train Loss: 0.7495 | Train Acc: 0.6960 | Train Bal Acc: 0.6934 | Train Macro F1: 0.6909 || Val Loss: 0.5020 | Val Acc: 0.8037 | Val Bal Acc: 0.7161 | Val Macro F1: 0.6882 | LR: backbone=2.93e-05, head=9.76e-05
#   -> New best val_macro_f1: 0.6882
# Epoch [2/50] | Train Loss: 0.6401 | Train Acc: 0.7411 | Train Bal Acc: 0.7425 | Train Macro F1: 0.7408 || Val Loss: 0.4855 | Val Acc: 0.8063 | Val Bal Acc: 0.7306 | Val Macro F1: 0.7081 | LR: backbone=2.71e-05, head=9.05e-05
#   -> New best val_macro_f1: 0.7081
# Epoch [3/50] | Train Loss: 0.5804 | Train Acc: 0.7658 | Train Bal Acc: 0.7657 | Train Macro F1: 0.7643 || Val Loss: 0.4403 | Val Acc: 0.8333 | Val Bal Acc: 0.7213 | Val Macro F1: 0.7243 | LR: backbone=2.38e-05, head=7.94e-05
#   -> New best val_macro_f1: 0.7243
# Epoch [4/50] | Train Loss: 0.5441 | Train Acc: 0.7875 | Train Bal Acc: 0.7876 | Train Macro F1: 0.7865 || Val Loss: 0.4637 | Val Acc: 0.8302 | Val Bal Acc: 0.7337 | Val Macro F1: 0.7180 | LR: backbone=1.97e-05, head=6.55e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [5/50] | Train Loss: 0.5100 | Train Acc: 0.7991 | Train Bal Acc: 0.7984 | Train Macro F1: 0.7976 || Val Loss: 0.4624 | Val Acc: 0.8185 | Val Bal Acc: 0.7365 | Val Macro F1: 0.7108 | LR: backbone=1.51e-05, head=5.01e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [6/50] | Train Loss: 0.5137 | Train Acc: 0.7939 | Train Bal Acc: 0.7944 | Train Macro F1: 0.7932 || Val Loss: 0.4747 | Val Acc: 0.8101 | Val Bal Acc: 0.7518 | Val Macro F1: 0.7115 | LR: backbone=1.04e-05, head=3.46e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [7/50] | Train Loss: 0.4694 | Train Acc: 0.8161 | Train Bal Acc: 0.8163 | Train Macro F1: 0.8156 || Val Loss: 0.4296 | Val Acc: 0.8354 | Val Bal Acc: 0.7367 | Val Macro F1: 0.7293 | LR: backbone=6.26e-06, head=2.07e-05
#   -> New best val_macro_f1: 0.7293
# Epoch [8/50] | Train Loss: 0.4603 | Train Acc: 0.8189 | Train Bal Acc: 0.8190 | Train Macro F1: 0.8181 || Val Loss: 0.4296 | Val Acc: 0.8423 | Val Bal Acc: 0.7333 | Val Macro F1: 0.7334 | LR: backbone=2.96e-06, head=9.64e-06
#   -> New best val_macro_f1: 0.7334
# Epoch [9/50] | Train Loss: 0.4387 | Train Acc: 0.8245 | Train Bal Acc: 0.8258 | Train Macro F1: 0.8245 || Val Loss: 0.4174 | Val Acc: 0.8439 | Val Bal Acc: 0.7425 | Val Macro F1: 0.7414 | LR: backbone=8.32e-07, head=2.54e-06
#   -> New best val_macro_f1: 0.7414
# Epoch [10/50] | Train Loss: 0.4585 | Train Acc: 0.8217 | Train Bal Acc: 0.8203 | Train Macro F1: 0.8199 || Val Loss: 0.4307 | Val Acc: 0.8434 | Val Bal Acc: 0.7428 | Val Macro F1: 0.7362 | LR: backbone=3.00e-05, head=1.00e-04
#   -> No improvement for 1/9 epoch(s)
# Epoch [11/50] | Train Loss: 0.4581 | Train Acc: 0.8117 | Train Bal Acc: 0.8119 | Train Macro F1: 0.8111 || Val Loss: 0.4569 | Val Acc: 0.8190 | Val Bal Acc: 0.7503 | Val Macro F1: 0.7293 | LR: backbone=2.98e-05, head=9.94e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [12/50] | Train Loss: 0.4084 | Train Acc: 0.8376 | Train Bal Acc: 0.8368 | Train Macro F1: 0.8365 || Val Loss: 0.4693 | Val Acc: 0.8238 | Val Bal Acc: 0.7315 | Val Macro F1: 0.7243 | LR: backbone=2.93e-05, head=9.76e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [13/50] | Train Loss: 0.3699 | Train Acc: 0.8551 | Train Bal Acc: 0.8543 | Train Macro F1: 0.8538 || Val Loss: 0.4282 | Val Acc: 0.8540 | Val Bal Acc: 0.7501 | Val Macro F1: 0.7467 | LR: backbone=2.84e-05, head=9.46e-05
#   -> New best val_macro_f1: 0.7467
# Epoch [14/50] | Train Loss: 0.3541 | Train Acc: 0.8601 | Train Bal Acc: 0.8601 | Train Macro F1: 0.8595 || Val Loss: 0.4803 | Val Acc: 0.8339 | Val Bal Acc: 0.7406 | Val Macro F1: 0.7304 | LR: backbone=2.71e-05, head=9.05e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [15/50] | Train Loss: 0.3425 | Train Acc: 0.8662 | Train Bal Acc: 0.8664 | Train Macro F1: 0.8660 || Val Loss: 0.4560 | Val Acc: 0.8423 | Val Bal Acc: 0.7348 | Val Macro F1: 0.7343 | LR: backbone=2.56e-05, head=8.54e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [16/50] | Train Loss: 0.3256 | Train Acc: 0.8746 | Train Bal Acc: 0.8736 | Train Macro F1: 0.8735 || Val Loss: 0.4703 | Val Acc: 0.8397 | Val Bal Acc: 0.7177 | Val Macro F1: 0.7263 | LR: backbone=2.38e-05, head=7.94e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [17/50] | Train Loss: 0.3110 | Train Acc: 0.8797 | Train Bal Acc: 0.8803 | Train Macro F1: 0.8799 || Val Loss: 0.4811 | Val Acc: 0.8471 | Val Bal Acc: 0.7200 | Val Macro F1: 0.7312 | LR: backbone=2.18e-05, head=7.27e-05
#   -> No improvement for 4/9 epoch(s)
# Epoch [18/50] | Train Loss: 0.2816 | Train Acc: 0.8931 | Train Bal Acc: 0.8939 | Train Macro F1: 0.8937 || Val Loss: 0.4625 | Val Acc: 0.8534 | Val Bal Acc: 0.7307 | Val Macro F1: 0.7505 | LR: backbone=1.97e-05, head=6.55e-05
#   -> New best val_macro_f1: 0.7505
# Epoch [19/50] | Train Loss: 0.2646 | Train Acc: 0.8979 | Train Bal Acc: 0.8975 | Train Macro F1: 0.8973 || Val Loss: 0.4712 | Val Acc: 0.8524 | Val Bal Acc: 0.7488 | Val Macro F1: 0.7530 | LR: backbone=1.74e-05, head=5.79e-05
#   -> New best val_macro_f1: 0.7530
# Epoch [20/50] | Train Loss: 0.2699 | Train Acc: 0.8952 | Train Bal Acc: 0.8956 | Train Macro F1: 0.8953 || Val Loss: 0.4762 | Val Acc: 0.8519 | Val Bal Acc: 0.7441 | Val Macro F1: 0.7561 | LR: backbone=1.51e-05, head=5.01e-05
#   -> New best val_macro_f1: 0.7561
# Epoch [21/50] | Train Loss: 0.2599 | Train Acc: 0.9003 | Train Bal Acc: 0.9003 | Train Macro F1: 0.9000 || Val Loss: 0.4943 | Val Acc: 0.8487 | Val Bal Acc: 0.7462 | Val Macro F1: 0.7520 | LR: backbone=1.27e-05, head=4.22e-05
#   -> No improvement for 1/9 epoch(s)
# Epoch [22/50] | Train Loss: 0.2360 | Train Acc: 0.9061 | Train Bal Acc: 0.9061 | Train Macro F1: 0.9059 || Val Loss: 0.5344 | Val Acc: 0.8455 | Val Bal Acc: 0.7093 | Val Macro F1: 0.7352 | LR: backbone=1.04e-05, head=3.46e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [23/50] | Train Loss: 0.2368 | Train Acc: 0.9068 | Train Bal Acc: 0.9068 | Train Macro F1: 0.9067 || Val Loss: 0.5147 | Val Acc: 0.8476 | Val Bal Acc: 0.7332 | Val Macro F1: 0.7478 | LR: backbone=8.26e-06, head=2.74e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [24/50] | Train Loss: 0.2383 | Train Acc: 0.9065 | Train Bal Acc: 0.9059 | Train Macro F1: 0.9058 || Val Loss: 0.5157 | Val Acc: 0.8466 | Val Bal Acc: 0.7306 | Val Macro F1: 0.7454 | LR: backbone=6.26e-06, head=2.07e-05
#   -> No improvement for 4/9 epoch(s)
# Epoch [25/50] | Train Loss: 0.2323 | Train Acc: 0.9114 | Train Bal Acc: 0.9116 | Train Macro F1: 0.9113 || Val Loss: 0.5079 | Val Acc: 0.8508 | Val Bal Acc: 0.7246 | Val Macro F1: 0.7480 | LR: backbone=4.48e-06, head=1.47e-05
#   -> No improvement for 5/9 epoch(s)
# Epoch [26/50] | Train Loss: 0.2250 | Train Acc: 0.9130 | Train Bal Acc: 0.9130 | Train Macro F1: 0.9130 || Val Loss: 0.5148 | Val Acc: 0.8529 | Val Bal Acc: 0.7436 | Val Macro F1: 0.7568 | LR: backbone=2.96e-06, head=9.64e-06
#   -> No improvement for 6/9 epoch(s)
# Epoch [27/50] | Train Loss: 0.2136 | Train Acc: 0.9177 | Train Bal Acc: 0.9171 | Train Macro F1: 0.9170 || Val Loss: 0.5234 | Val Acc: 0.8534 | Val Bal Acc: 0.7197 | Val Macro F1: 0.7479 | LR: backbone=1.73e-06, head=5.54e-06
#   -> No improvement for 7/9 epoch(s)
# Epoch [28/50] | Train Loss: 0.2143 | Train Acc: 0.9187 | Train Bal Acc: 0.9184 | Train Macro F1: 0.9180 || Val Loss: 0.5146 | Val Acc: 0.8503 | Val Bal Acc: 0.7384 | Val Macro F1: 0.7477 | LR: backbone=8.32e-07, head=2.54e-06
#   -> No improvement for 8/9 epoch(s)
# Epoch [29/50] | Train Loss: 0.2131 | Train Acc: 0.9169 | Train Bal Acc: 0.9171 | Train Macro F1: 0.9170 || Val Loss: 0.5090 | Val Acc: 0.8587 | Val Bal Acc: 0.7354 | Val Macro F1: 0.7585 | LR: backbone=2.84e-07, head=7.15e-07
#   -> New best val_macro_f1: 0.7585
# Epoch [30/50] | Train Loss: 0.2096 | Train Acc: 0.9168 | Train Bal Acc: 0.9164 | Train Macro F1: 0.9163 || Val Loss: 0.5154 | Val Acc: 0.8529 | Val Bal Acc: 0.7323 | Val Macro F1: 0.7471 | LR: backbone=3.00e-05, head=1.00e-04
#   -> No improvement for 1/9 epoch(s)
# Epoch [31/50] | Train Loss: 0.2265 | Train Acc: 0.9116 | Train Bal Acc: 0.9115 | Train Macro F1: 0.9113 || Val Loss: 0.6118 | Val Acc: 0.8376 | Val Bal Acc: 0.6878 | Val Macro F1: 0.7149 | LR: backbone=3.00e-05, head=9.98e-05
#   -> No improvement for 2/9 epoch(s)
# Epoch [32/50] | Train Loss: 0.2149 | Train Acc: 0.9168 | Train Bal Acc: 0.9170 | Train Macro F1: 0.9170 || Val Loss: 0.5333 | Val Acc: 0.8534 | Val Bal Acc: 0.7276 | Val Macro F1: 0.7483 | LR: backbone=2.98e-05, head=9.94e-05
#   -> No improvement for 3/9 epoch(s)
# Epoch [33/50] | Train Loss: 0.1990 | Train Acc: 0.9209 | Train Bal Acc: 0.9211 | Train Macro F1: 0.9210 || Val Loss: 0.6238 | Val Acc: 0.8376 | Val Bal Acc: 0.7043 | Val Macro F1: 0.7295 | LR: backbone=2.96e-05, head=9.86e-05
#   -> No improvement for 4/9 epoch(s)
# Epoch [34/50] | Train Loss: 0.2046 | Train Acc: 0.9234 | Train Bal Acc: 0.9233 | Train Macro F1: 0.9232 || Val Loss: 0.6060 | Val Acc: 0.8392 | Val Bal Acc: 0.7361 | Val Macro F1: 0.7399 | LR: backbone=2.93e-05, head=9.76e-05
#   -> No improvement for 5/9 epoch(s)
# Epoch [35/50] | Train Loss: 0.1890 | Train Acc: 0.9273 | Train Bal Acc: 0.9269 | Train Macro F1: 0.9270 || Val Loss: 0.6249 | Val Acc: 0.8550 | Val Bal Acc: 0.7083 | Val Macro F1: 0.7422 | LR: backbone=2.89e-05, head=9.62e-05
#   -> No improvement for 6/9 epoch(s)
# Epoch [36/50] | Train Loss: 0.1763 | Train Acc: 0.9330 | Train Bal Acc: 0.9332 | Train Macro F1: 0.9331 || Val Loss: 0.6176 | Val Acc: 0.8534 | Val Bal Acc: 0.7193 | Val Macro F1: 0.7447 | LR: backbone=2.84e-05, head=9.46e-05
#   -> No improvement for 7/9 epoch(s)
# Epoch [37/50] | Train Loss: 0.1818 | Train Acc: 0.9343 | Train Bal Acc: 0.9350 | Train Macro F1: 0.9349 || Val Loss: 0.6420 | Val Acc: 0.8492 | Val Bal Acc: 0.7160 | Val Macro F1: 0.7418 | LR: backbone=2.78e-05, head=9.26e-05
#   -> No improvement for 8/9 epoch(s)
# Epoch [38/50] | Train Loss: 0.1698 | Train Acc: 0.9344 | Train Bal Acc: 0.9344 | Train Macro F1: 0.9343 || Val Loss: 0.6302 | Val Acc: 0.8524 | Val Bal Acc: 0.7243 | Val Macro F1: 0.7497 | LR: backbone=2.71e-05, head=9.05e-05
#   -> No improvement for 9/9 epoch(s)
# Early stopping triggered at epoch 38
#
#  Saved preprocessing objects to: preprocessing_fold_5.pkl
# Saved full checkpoint to: checkpoint_fold_5.pth
#  Saved model weights to: best_model_fold_5.pth

# %%
# ============================================================
# OPTION 1: LOAD FULL MODEL (Has METADATA)
# ============================================================

def load_pretrained_model_full(fold_num=1, device='cuda'):
    """
    Load pretrained model với metadata branch

    Args:
        fold_num: Fold number to load (1-5)
        device: 'cuda' or 'cpu'

    Returns:
        model: Loaded model
        preprocessing: Dictionary containing encoder, scaler, etc.
        checkpoint: Full checkpoint info
    """
    # Load checkpoint
    checkpoint_path = f'checkpoint_fold_{fold_num}.pth'
    checkpoint = torch.load(checkpoint_path, map_location=device)

    # Load preprocessing
    preprocessing_path = f'preprocessing_fold_{fold_num}.pkl'
    with open(preprocessing_path, 'rb') as f:
        preprocessing = pickle.load(f)

    # Create model
    model = MultiModalSkinNet(
        metadata_dim=checkpoint['metadata_dim'],
        num_classes=checkpoint['num_classes']
    ).to(device)

    # Load weights
    model.load_state_dict(checkpoint['model_state_dict'])

    print(f"   Loaded model from fold {fold_num}")
    print(f"   - Best epoch: {checkpoint['best_epoch']}")
    print(f"   - Best val F1: {checkpoint['best_val_f1']:.4f}")
    print(f"   - Metadata dim: {checkpoint['metadata_dim']}")
    print(f"   - Num classes: {checkpoint['num_classes']}")

    return model, preprocessing, checkpoint

# %%
# ============================================================
# OPTION 2: LOAD IMAGE-ONLY MODEL (No METADATA)
# ============================================================

class ImageOnlySkinNet(nn.Module):
    """Model chỉ dùng image features, không dùng metadata"""
    def __init__(self, num_classes=4, pretrained_model=None):
        super().__init__()

        if pretrained_model is not None:
            # Copy backbone from pretrained model
            self.shared_backbone = pretrained_model.shared_backbone
            self.pool = pretrained_model.pool
            self.img_dropout = pretrained_model.img_dropout
        else:
            # Initialize new
            self.shared_backbone = make_single_channel_efficientnet(pretrained=True)
            self.pool = nn.AdaptiveAvgPool2d((1, 1))
            self.img_dropout = nn.Dropout(0.5)

        # NEW classifier - only image features (3840), NO metadata
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(1280 * 3, 256),  # 3840 -> 256
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def extract(self, img):
        """Extract features from 1 grayscale image"""
        return torch.flatten(self.pool(self.shared_backbone(img)), 1)

    def forward(self, img_R, img_G, img_B):
        feat_R = self.extract(img_R)
        feat_G = self.extract(img_G)
        feat_B = self.extract(img_B)

        img_feat = torch.cat([feat_R, feat_G, feat_B], dim=1)
        img_feat = self.img_dropout(img_feat)

        return self.classifier(img_feat)


def load_pretrained_model_image_only(fold_num=1, num_classes_new=4, device='cuda'):
    """
    Load pretrained model WITHOUT metadata branch (image only)

    Args:
        fold_num: Fold number to load (1-5)
        num_classes_new: Number of classes for new task (can be different)
        device: 'cuda' or 'cpu'

    Returns:
        model: ImageOnlySkinNet model with pretrained backbone
        checkpoint: Checkpoint info
    """
    # Load checkpoint
    checkpoint_path = f'checkpoint_fold_{fold_num}.pth'
    checkpoint = torch.load(checkpoint_path, map_location=device)

    # Create full model temporarily
    temp_model = MultiModalSkinNet(
        metadata_dim=checkpoint['metadata_dim'],
        num_classes=checkpoint['num_classes']
    )
    temp_model.load_state_dict(checkpoint['model_state_dict'])

    # Create image-only model with pretrained backbone
    model = ImageOnlySkinNet(
        num_classes=num_classes_new,
        pretrained_model=temp_model
    ).to(device)

    print(f"   Loaded IMAGE-ONLY model from fold {fold_num}")
    print(f"   - Pretrained on {checkpoint['num_classes']} classes")
    print(f"   - New model has {num_classes_new} classes")
    print(f"   - Backbone is pretrained, classifier is NEW")
    print(f"   - Best val F1 (original): {checkpoint['best_val_f1']:.4f}")

    return model, checkpoint

# %%
# ============================================================
# SEE INFORMATION OF CHECKPOINT
# ============================================================

def inspect_checkpoint(fold_num=1):
    """Print checkpoint information"""
    import torch
    import pickle

    # Load checkpoint
    checkpoint = torch.load(f'checkpoint_fold_{fold_num}.pth', map_location='cpu')

    print(f"\n{'='*60}")
    print(f"CHECKPOINT FOLD {fold_num}")
    print(f"{'='*60}")
    for key, value in checkpoint.items():
        if key != 'model_state_dict':
            print(f"{key:20s}: {value}")
    print(f"{'='*60}\n")

    # Load preprocessing
    preprocessing = pickle.load(open(f'preprocessing_fold_{fold_num}.pkl', 'rb'))

    print(f"{'='*60}")
    print(f"PREPROCESSING FOLD {fold_num}")
    print(f"{'='*60}")
    for key, value in preprocessing.items():
        if key not in ['encoder', 'scaler']:
            print(f"{key:20s}: {value}")
        else:
            print(f"{key:20s}: {type(value).__name__}")
    print(f"{'='*60}\n")

# Usage:
# inspect_checkpoint(fold_num=1)

# %%
def evaluate_model(model, dataloader, device):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for img_R, img_G, img_B, metadata, labels in dataloader:
            img_R = img_R.to(device)
            img_G = img_G.to(device)
            img_B = img_B.to(device)
            metadata = metadata.to(device).float()
            labels = labels.to(device).long()

            outputs = model(img_R, img_G, img_B, metadata)
            _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)
    bal_acc = balanced_accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='macro', zero_division=0)
    recall = recall_score(all_labels, all_preds, average='macro', zero_division=0)
    f1 = f1_score(all_labels, all_preds, average='macro', zero_division=0)
    cm = confusion_matrix(all_labels, all_preds)

    return acc, bal_acc, precision, recall, f1, cm, all_labels, all_preds

# %%
plt.figure(figsize=(10, 6))

for i in range(len(all_fold_train_losses)):
    plt.plot(all_fold_train_losses[i], label=f"Fold {i+1} Train Loss")
    plt.plot(all_fold_val_losses[i], linestyle='--', label=f"Fold {i+1} Val Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Learning Curves - Loss Across All Folds")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

for i in range(len(all_fold_train_accs)):
    plt.plot(all_fold_train_accs[i], label=f"Fold {i+1} Train Acc")
    plt.plot(all_fold_val_accs[i], linestyle='--', label=f"Fold {i+1} Val Acc")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Learning Curves - Accuracy Across All Folds")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

for i in range(len(all_fold_train_bal_accs)):
    plt.plot(all_fold_train_bal_accs[i], label=f"Fold {i+1} Train Bal Acc")
    plt.plot(all_fold_val_bal_accs[i], linestyle='--', label=f"Fold {i+1} Val Bal Acc")

plt.xlabel("Epoch")
plt.ylabel("Balanced Accuracy")
plt.title("Learning Curves - Balanced Accuracy Across All Folds")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

for i in range(len(all_fold_train_f1s)):
    plt.plot(all_fold_train_f1s[i], label=f"Fold {i+1} Train F1")
    plt.plot(all_fold_val_f1s[i], linestyle='--', label=f"Fold {i+1} Val F1")

plt.xlabel("Epoch")
plt.ylabel("Macro F1")
plt.title("Learning Curves - Macro F1 Across All Folds")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

for i in range(len(all_fold_val_losses)):
    plt.plot(all_fold_val_losses[i], label=f"Fold {i+1} Val Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Validation Loss Across All Folds")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import torch.nn.functional as F

def plot_roc_curve(model, loader, device, label_names):
    model.eval()
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for img_R, img_G, img_B, meta, labels in loader:  # ← unpack tuple
            img_R = img_R.to(device)
            img_G = img_G.to(device)
            img_B = img_B.to(device)
            meta = meta.to(device)

            outputs = model(img_R, img_G, img_B, meta)
            probs = F.softmax(outputs, dim=1)

            all_probs.append(probs.cpu().numpy())
            all_labels.append(labels.numpy())

    all_probs = np.concatenate(all_probs)
    all_labels = np.concatenate(all_labels)

    n_classes = len(label_names)
    plt.figure(figsize=(8, 6))

    for i in range(n_classes):
        fpr, tpr, _ = roc_curve((all_labels == i).astype(int), all_probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f"{label_names[i]} (AUC = {roc_auc:.4f})")

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (One-vs-Rest)')
    plt.legend(loc='lower right')
    plt.tight_layout()
    plt.show()


def compute_log_loss(model, loader, device):
    from sklearn.metrics import log_loss

    model.eval()
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for img_R, img_G, img_B, meta, labels in loader:  # ← unpack tuple
            img_R = img_R.to(device)
            img_G = img_G.to(device)
            img_B = img_B.to(device)
            meta = meta.to(device)

            outputs = model(img_R, img_G, img_B, meta)
            probs = F.softmax(outputs, dim=1)

            all_probs.append(probs.cpu().numpy())
            all_labels.append(labels.numpy())

    all_probs = np.concatenate(all_probs)
    all_labels = np.concatenate(all_labels)

    loss = log_loss(all_labels, all_probs)
    print(f"Log Loss: {loss:.4f}")
    return loss

# %%
from sklearn.metrics import cohen_kappa_score, matthews_corrcoef, classification_report
import seaborn as sns


label_names = ['bcc', 'bkl', 'mel', 'nv']


def extra_metrics(all_labels, all_preds):
    kappa = cohen_kappa_score(all_labels, all_preds)
    mcc = matthews_corrcoef(all_labels, all_preds)
    print(f"Cohen's Kappa: {kappa:.4f}")
    print(f"MCC:           {mcc:.4f}")
    return kappa, mcc

for fr in fold_results:
    fold_idx = fr['fold'] - 1
    _, train_fold_df, val_fold_df = folds[fold_idx]
    _, val_loader, metadata_dim = build_loaders_for_fold(train_fold_df, val_fold_df)

    model_eval = MultiModalSkinNet(metadata_dim=metadata_dim, num_classes=4).to(device)
    model_eval.load_state_dict(torch.load(f"best_model_fold_{fr['fold']}.pth", map_location=device))

    acc, bal_acc, precision, recall, f1, cm, all_labels, all_preds = evaluate_model(
        model_eval, val_loader, device
    )

    # confusion matrix

    sns.heatmap(cm, annot=True, fmt='d',
                xticklabels=label_names,
                yticklabels=label_names,
                cmap='Blues')


    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d',
                xticklabels=label_names, yticklabels=label_names, cmap='Blues')
    plt.title(f"Confusion Matrix - Fold {fr['fold']} | F1: {f1:.4f}")
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()

    print(f"\nFold {fr['fold']} — Per-class metrics:")
    print(classification_report(all_labels, all_preds, target_names=label_names, digits=4))

    kappa, mcc = extra_metrics(all_labels, all_preds)
    plot_roc_curve(model_eval, val_loader, device, label_names)
    compute_log_loss(model_eval, val_loader, device)
# Out:
# Fold 1 — Per-class metrics:
#               precision    recall  f1-score   support
#
#          bcc     0.8571    0.7723    0.8125       101
#          bkl     0.7947    0.6742    0.7295       178
#          mel     0.5381    0.5853    0.5607       217
#           nv     0.9174    0.9296    0.9235      1350
#
#     accuracy                         0.8559      1846
#    macro avg     0.7768    0.7403    0.7565      1846
# weighted avg     0.8577    0.8559    0.8561      1846
#
# Cohen's Kappa: 0.6668
# MCC:           0.6672
# Log Loss: 0.4723
# Fold 2 — Per-class metrics:
#               precision    recall  f1-score   support
#
#          bcc     0.7130    0.9011    0.7961        91
#          bkl     0.7516    0.5450    0.6319       211
#          mel     0.5792    0.5837    0.5814       257
#           nv     0.9026    0.9238    0.9131      1365
#
#     accuracy                         0.8358      1924
#    macro avg     0.7366    0.7384    0.7306      1924
# weighted avg     0.8339    0.8358    0.8324      1924
#
# Cohen's Kappa: 0.6393
# MCC:           0.6404
# Log Loss: 0.4626
# Fold 3 — Per-class metrics:
#               precision    recall  f1-score   support
#
#          bcc     0.7982    0.7436    0.7699       117
#          bkl     0.8824    0.5747    0.6961       261
#          mel     0.5058    0.6422    0.5659       204
#           nv     0.9090    0.9393    0.9239      1318
#
#     accuracy                         0.8453      1900
#    macro avg     0.7738    0.7249    0.7389      1900
# weighted avg     0.8552    0.8453    0.8447      1900
#
# Cohen's Kappa: 0.6724
# MCC:           0.6753
# Log Loss: 0.5434
# Fold 4 — Per-class metrics:
#               precision    recall  f1-score   support
#
#          bcc     0.7596    0.8404    0.7980        94
#          bkl     0.8038    0.5826    0.6755       218
#          mel     0.5795    0.7018    0.6349       218
#           nv     0.9331    0.9359    0.9345      1341
#
#     accuracy                         0.8626      1871
#    macro avg     0.7690    0.7652    0.7607      1871
# weighted avg     0.8681    0.8626    0.8625      1871
#
# Cohen's Kappa: 0.6986
# MCC:           0.6999
# Log Loss: 0.4329
# Fold 5 — Per-class metrics:
#               precision    recall  f1-score   support
#
#          bcc     0.8317    0.7568    0.7925       111
#          bkl     0.7933    0.6147    0.6927       231
#          mel     0.6221    0.6221    0.6221       217
#           nv     0.9060    0.9482    0.9266      1331
#
#     accuracy                         0.8587      1890
#    macro avg     0.7883    0.7354    0.7585      1890
# weighted avg     0.8552    0.8587    0.8552      1890
#
# Cohen's Kappa: 0.6882
# MCC:           0.6903
# Log Loss: 0.5090

# %%
print(f"\n{'='*60}")
print("FINAL RESULTS ACROSS ALL FOLDS")
print(f"{'='*60}")
print(f"{'Fold':<8} {'Best Epoch':<12} {'Val Acc':<10} {'Val Bal Acc':<14} {'Val F1'}")
print(f"{'='*60}")
for fr in fold_results:
    print(f"{fr['fold']:<8} {fr['best_epoch']:<12} {fr['best_val_acc']:.4f}     {fr['best_val_bal_acc']:.4f}         {fr['best_val_f1']:.4f}")
print(f"{'='*60}")
best_f1s = [fr['best_val_f1'] for fr in fold_results]
best_accs = [fr['best_val_acc'] for fr in fold_results]
print(f"Mean F1:  {np.mean(best_f1s):.4f} ± {np.std(best_f1s):.4f}")
print(f"Mean Acc: {np.mean(best_accs):.4f} ± {np.std(best_accs):.4f}")
# Out:
# ============================================================
# FINAL RESULTS ACROSS ALL FOLDS
# ============================================================
# Fold     Best Epoch   Val Acc    Val Bal Acc    Val F1
# ============================================================
# 1        29           0.8559     0.7403         0.7565
# 2        14           0.8358     0.7384         0.7306
# 3        19           0.8453     0.7249         0.7389
# 4        15           0.8626     0.7652         0.7607
# 5        29           0.8587     0.7354         0.7585
# ============================================================
# Mean F1:  0.7491 ± 0.0120
# Mean Acc: 0.8517 ± 0.0098

# %%
print(f"\n{'='*60}")
print("FINAL RESULTS ACROSS ALL FOLDS")
print(f"{'='*60}")
print(f"{'Fold':<8} {'Best Epoch':<12} {'Val Acc':<10} {'Val Bal Acc':<14} {'Val F1'}")
print(f"{'='*60}")
for fr in fold_results:
    print(f"{fr['fold']:<8} {fr['best_epoch']:<12} {fr['best_val_acc']:.4f}     {fr['best_val_bal_acc']:.4f}         {fr['best_val_f1']:.4f}")
print(f"{'='*60}")
best_f1s = [fr['best_val_f1'] for fr in fold_results]
best_accs = [fr['best_val_acc'] for fr in fold_results]
print(f"Mean F1:  {np.mean(best_f1s):.4f} ± {np.std(best_f1s):.4f}")
print(f"Mean Acc: {np.mean(best_accs):.4f} ± {np.std(best_accs):.4f}")
# Out:
# ============================================================
# FINAL RESULTS ACROSS ALL FOLDS
# ============================================================
# Fold     Best Epoch   Val Acc    Val Bal Acc    Val F1
# ============================================================
# 1        29           0.8559     0.7403         0.7565
# 2        14           0.8358     0.7384         0.7306
# 3        19           0.8453     0.7249         0.7389
# 4        15           0.8626     0.7652         0.7607
# 5        29           0.8587     0.7354         0.7585
# ============================================================
# Mean F1:  0.7491 ± 0.0120
# Mean Acc: 0.8517 ± 0.0098

# %% [markdown]
# ---
